# %%
# Import statements
import numpy as np
import random as rand
import os
import pandas
import time

# %%
# This cell contains all Connect4 related functions.

# This is a wrapper class that holds the logic engine and returns a decision.
class logic_engine_wrapper:

    # Defaults logic_engine to 0 so that it will just move over one space each turn.
    def __init__(self,logic_engine=0):
        self.logic_engine = logic_engine

    # Returns the logic_engine's move based on the provided board.
    def get_move(self,board):
        if type(self.logic_engine) is int:
            if self.logic_engine >= 6:
                self.logic_engine = 0
                return 6
            else:
                self.logic_engine += 1
                return self.logic_engine - 1
        else:
            output = self.logic_engine.get_output_vector(board.get_board_vector())
            greatest = 0
            for i in range(len(output)):
                if output[i] > output[greatest]:
                    greatest = i
            return greatest
                    
# This class represents a Connect4 board and contains all necessary utilities for it.
# On boards player1 = 1, player2 = -1, and blank = 0.
# The higher the first index the higher on the board i.e. index [5][6] is the top right corner of the board.
class game_board:

    # Creates a 7 x 6 game board.
    def __init__(self):
        self.board = [[0.0 for _ in range(7)] for _ in range(6)]

    # Prints the current game board.
    def print_board(self,player1_symbol='@',player2_symbol='#',clear=False):
        if clear:
            os.system('cls')
        for row in self.board[::-1]:
            print('|',end='')
            for num in row:
                symbol = player1_symbol if num == 1 else (player2_symbol if num == -1 else ' ')
                print(symbol,end='')
            print('|')
        print('---------')
        print(' 1234567 ')

    # Drops a piece into the indicated slot using a range of [0,6]
    def drop_piece(self,slot,player):
        if slot > 6 or slot < 0:
            return False
        else:
            for i in range(6):
                if self.board[i][slot] == 0:
                    self.board[i][slot] = player
                    return True
            return False

    # Returns the board squashed into a numpy array. (This is a utility function for net use)
    def get_board_vector(self):
        board_vector = []
        for row in self.board:
            board_vector += row
        return np.array(board_vector)

    # Returns a player if one of them as won otherwise returns 0.
    def get_winner(self):
        # Checks rows.
        for row in self.board:
            previous = None
            count = 0
            for num in row:
                if count >= 4 and previous != 0:
                    return previous
                if num == previous:
                    count += 1
                else:
                    previous = num
                    count = 1
        # Checks columns.
        for x in range(7):
            previous = None
            count = 0
            for y in range(6):
                num = self.board[y][x]
                if count >= 4 and previous != 0:
                    return previous
                if num == previous:
                    count += 1
                else:
                    previous = num
                    count = 1
        # Checks diagonals.
        for y in range(6):
            for x in range(7):
                num = self.board[y][x]
                if num != 0 and y < 3:
                    if x < 4:
                        if num == self.board[y+1][x+1] and num == self.board[y+2][x+2] and num == self.board[y+3][x+3]:
                            return num
                    elif x > 2:
                        if num == self.board[y+1][x-1] and num == self.board[y+2][x-2] and num == self.board[y+3][x-3]:
                            return num

        return 0


# This function enables the user to play against a logic_engine or lets two logic_engines play against each other.
def play_game(logic_engines=[logic_engine_wrapper()],verbose=True,ai_delay=0.2):
    board = game_board()
    current_player = 1 if rand.choice([True,False]) else -1
    max_num_of_turns = 6 * 7
    for turn in range(max_num_of_turns):
        if verbose:
            board.print_board(clear=True)
        if len(logic_engines) == 2:
            if verbose:
                print("Thinking...")
            time.sleep(ai_delay)
            slot = None
            if current_player == 1:
                proxy_board = game_board()
                for y in range(len(proxy_board.board)):
                    for x in range(len(proxy_board.board[y])):
                        proxy_board.board[y][x] = -1 * board.board[y][x]
                slot = logic_engines[0].get_move(proxy_board)
            else:
                slot = logic_engines[1].get_move(board)
            board.drop_piece(slot,current_player)
        else:
            if current_player == 1:
                slot = int(input('Input a slot: ')) - 1
                board.drop_piece(slot,current_player)
            else:
                if verbose:
                    print("Thinking...")
                time.sleep(ai_delay)
                slot = logic_engines[0].get_move(board)
                board.drop_piece(slot,current_player)
        winner = board.get_winner()
        if winner != 0:
            if verbose:
                board.print_board(clear=True)
            return winner
        else:
            current_player = 1 if current_player == -1 else -1
        if turn == (6 * 7) - 1 and verbose:
            board.print_board(clear=True)
    return 0

# %%
#Non-linear functions are declared in this cell.

#Sigmoid function.
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# Info String Seperators:
net_section_seperator = '|'
net_sub_section_seperator = ':' # i.e. each hidden layer and each bias layer
net_matrix_row_seperator = '>'
net_vector_index_seperator = ','

# %%
# Feedforward network class that's used.
class net:
    
    # wiki_net class constructor.
    def __init__(self,input_size,hidden_layers,non_linears=sigmoid,use_biases=True,name="N/A"):
        self.hidden_layers = []
        self.non_linears = []
        self.biases = []
        self.name = name
        if type(non_linears) != list:
            non_linears = [non_linears] * len(hidden_layers) 
            previous_size = input_size
        elif len(non_linears) == 1:
            non_linears *= len(hidden_layers)
        for i in range(len(hidden_layers)):
            self.hidden_layers.append(2 * np.random.random((previous_size,hidden_layers[i])) - 1)
            self.non_linears.append(non_linears[i])
            self.biases.append(2 * np.random.random(hidden_layers[i]) - 1 if use_biases else np.zeros(hidden_layers[i]))
            previous_size = hidden_layers[i]
    
    # Gets the output vector for a given input vector.
    def get_output_vector(self,input_vector):
        output_vector = input_vector
        for i in range(len(self.hidden_layers)):
            output_vector = self.non_linears[i](np.dot(output_vector,self.hidden_layers[i] + self.biases[i]))
        return output_vector
    
    # Returns a string that contains all of the network's features in the following order, [Name, Score, Hidden_Layers, Biases]
    def generate_info_string(self,score=0):
        info_string = f'{self.name}{net_section_seperator}{score}{net_section_seperator}'
        count_1 = 0
        count_2 = 0
        count_3 = 0
        for layer in self.hidden_layers:
            for vector in layer:
                for index in vector:
                    info_string += f'{index}'
                    info_string += net_vector_index_seperator if count_1 != len(vector) - 1 else ''
                    count_1 += 1
                count_1 = 0
                info_string += net_matrix_row_seperator if count_2 != len(layer) - 1 else ''
                count_2 += 1
            count_2 = 0
            info_string += net_sub_section_seperator if count_3 != len(self.hidden_layers) - 1 else ''
            count_3 += 1
        info_string += net_section_seperator
        count_1 = 0
        count_2 = 0
        for bias in self.biases:
            for index in bias:
                info_string += f'{index}'
                info_string += net_vector_index_seperator if count_1 != len(bias) - 1 else ''
                count_1 += 1
            count_1 = 0
            info_string += net_sub_section_seperator if count_2 != len(self.biases) - 1 else ''
            count_2 += 1
        return info_string
    
    # Loads the net's attribute's from a given string and returns it's score.
    # String Format is listed above the generate_info_string method
    def load_info_from_string(self,info_string,non_linear=sigmoid):
        sections = info_string.split(net_section_seperator)
        self.name = sections[0]
        score = float(sections[1])
        self.hidden_layers = []
        self.biases = []
        self.non_linears = [non_linear]
        hidden_layer_sections = sections[2].split(net_sub_section_seperator)
        for layer in hidden_layer_sections:
            vectors = []
            for text_vector in layer.split(net_matrix_row_seperator):
                vector = []
                for index in text_vector.split(net_vector_index_seperator):
                    vector.append(float(index))
                vectors.append(vector)
            self.hidden_layers.append(np.array(vectors))
        self.non_linears *= len(self.hidden_layers)
        text_biases = sections[3].split(net_sub_section_seperator)
        for text_bias in text_biases:
            bias = []
            for index in text_bias.split(net_vector_index_seperator):
                bias.append(float(index))
            self.biases.append(np.array(bias))
        return score

# %%
# All functions related to saving and loading data are in this cell.

# Saves the given wrapped net population.
def save_wrapped_net_population(population,name,generation):
    try:
        file = open(f'Populations/{name}.snp','w')
        file.write(f'Generation {generation}')
        for wrapped_net in population:
            file.write(f'\n{wrapped_net[0].generate_info_string(wrapped_net[1])}')
        file.close()
    except:
        print(f'Failed to save population : {name}')
        
# Loads a net population from a given file in format (population,generation)
def load_wrapped_net_population(name):
    file = None
    try:
        file = open(f'Populations/{name}.snp','r')
    except:
        print(f'Failed to find file for population : {name}')
        return None
    if file != None:
        contents = file.read().split('\n')
        generation = int(contents[0].split(' ')[1])
        population = []
        for val in contents[1:]:
            net = generate_standard_net()
            score = net.load_info_from_string(val)
            population.append((net,score))
        return (population,generation)

# %%
# Generates a net_net with preset values (this is basically a way to make net generation easier).
def generate_standard_net(name="N/A"): 
    return net(input_size=42,hidden_layers=[7],name=name)
    #return net(input_size=42,hidden_layers=[20,10,7],name=name)
    #return net_net(input_size=5,hidden_layers=[3,2,1],name=name)

# %%
# Genetic evolution related functions are declared in this cell.

# Breeds two nets using indexed addition and the specified weight, mates child with a random net if mutating.
def breed_nets(net_1,net_2,net_1_weight=0.5,mutation=False,non_linear=sigmoid,name="N/A"):
    hidden_layers = []
    biases = []
    non_linears = []
    for i in range(len(net_1.hidden_layers)):
        #hidden_layers.append((net_1.hidden_layers[i] * net_1_weight) + (net_2.hidden_layers[i] * (1 - net_1_weight)))
        #biases.append((net_1.biases[i] * net_1_weight) + (net_2.biases[i] * (1 - net_1_weight)))
        non_linears.append(non_linear)
        hidden_layers.append([])
        biases.append([])
        for j in range(len(net_1.hidden_layers[i])):
            hidden_layers[i].append((rand.choice([net_1,net_2])).hidden_layers[i][j])
        hidden_layers[i] = np.array(hidden_layers[i])
        for j in range(len(net_1.biases[i])):
            biases[i].append((rand.choice([net_1,net_2])).biases[i][j])
        biases[i] = np.array(biases[i])
    child = generate_standard_net(name=name)
    child.hidden_layers = hidden_layers
    child.biases = biases
    child.non_linears = non_linears
    if mutation:
        return breed_nets(child,generate_standard_net(),np.random.random(1)[0],name=name)
    else:
        return child

# Breeds a population of ordered wrapped nets.
def breed_wrapped_net_popultation(old_population,generation):
    avg_score = 0
    old_size = len(old_population)
    for wrapped_net in old_population:
        avg_score += wrapped_net[1]
    avg_score /= len(old_population)
    new_population = []
    rand.shuffle(old_population)
    for wrapped_net in old_population:
        if wrapped_net[1] >= avg_score and len(new_population) < len(old_population) / 2:
            new_population.append(wrapped_net)
    old_population = new_population
    new_population = []
    child_num = 0
    rand.shuffle(old_population)
    while len(old_population) > 1:
        wrapped_nets = [old_population.pop(),old_population.pop()]
        child_weights = [0.7,0.3]
        rand.shuffle(child_weights)
        score_sum = wrapped_nets[0][1] + wrapped_nets[1][1]
        if score_sum > 0:
            child_weights = [wrapped_nets[0][1] / score_sum,0.5]
            if child_weights[0] == child_weights[1]:
                child_weights[0] = np.random.random(1)[0]
        child_num += 1
        child_1 = breed_nets(wrapped_nets[0][0],wrapped_nets[1][0],child_weights[0],mutation=np.random.random(1)[0] > 0.95,name=f'Net : {child_num} (Generation : {generation})')
        child_num += 1
        child_2 = breed_nets(wrapped_nets[0][0],wrapped_nets[1][0],child_weights[1],mutation=np.random.random(1)[0] > 0.95,name=f'Net : {child_num} (Generation : {generation})')
        new_population.append((child_1,0))
        new_population.append((child_2,0))
        if avg_score <= 0:
            if np.random.random(1)[0] > 0.5:
                new_population = add_wrapped_net(new_population,wrapped_nets[0])
            else:
                new_population = add_wrapped_net(new_population,wrapped_nets[1])
        else:
            for wrapped_net in wrapped_nets:
                if wrapped_net[1] >= avg_score:
                        new_population = add_wrapped_net(new_population,wrapped_net)
    if len(old_population) <= 3:
            child_num += 1
            new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
            child_num += 1
            new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
            child_num += 1
            new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
    while len(old_population) > 0:
        new_population = add_wrapped_net(new_population,old_population.pop())
    if len(new_population) <= 0:
        for _ in range(8):
            child_num += 1
            new_population.append((generate_standard_net_net(name=f'Net : {child_num} (Generation : {generation})'),0))
    while len(new_population) < old_size:
        child_num += 1
        new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
   # if generation % 4:
           # child_num += 1
           # new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
    if generation % 200 == 0:
        new_population = new_population[:20]
        for _ in range(25):
            child_num += 1
            new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
    return new_population
    
# Subjects a population to natural selection for the given number of generations.
def subject_popultaion_to_natural_selection(population,starting_generation,name,num_of_generations=100,verbose_crawl=False):
    for i in range(num_of_generations):
        current_generation = starting_generation + i
        print(f'Beginning Natural Selection For Generation : {current_generation} | Population Size : {len(population)}')
        new_population = []
        high_score = 0
        count = 0
        start = time.time()
        for wrapped_net in population:
            new_population.append((wrapped_net[0],0))
        for i in range(len(new_population) - 1):
            for j in range(len(new_population) - i):
                if j != 0:
                    logic_engine_1 = logic_engine_wrapper(logic_engine=population[i][0])
                    logic_engine_2 = logic_engine_wrapper(logic_engine=population[i+j][0])
                    result = play_game(logic_engines=[logic_engine_1,logic_engine_2],verbose=False,ai_delay=0)
                    if result == 1:
                        new_population[i] = (new_population[i][0],new_population[i][1]+1)
                    elif result == -1:
                        new_population[i] = (new_population[i+j][0],new_population[i+j][1]+1)
        proxy_pop = []
        for wrapped_net in new_population:
            add_wrapped_net(proxy_pop,wrapped_net)
            if wrapped_net[1] > high_score:
                high_score = wrapped_net[1]
        new_population = proxy_pop
        end = time.time()
        print(f'Generation {current_generation} High Score : {high_score} | Duration : {end - start} Secs')
        population = breed_wrapped_net_popultation(new_population,current_generation + 1)
        save_wrapped_net_population(population,name,current_generation + 1)
        print(f'Generation {current_generation + 1} Bred')

# Generates a starting population of nets. The nets are in a tuple wrapper of format (net,score)
def generate_base_wrapped_net_population(size=100):
    return [(generate_standard_net(f'Net : {i + 1} (Generation : 0)'),0) for i in range(size)]

# Adds a net wrapper to the given array in order of greatest score.
def add_wrapped_net(array,wrapped_net):
    if len(array) == 0:
        array.append(wrapped_net)
    else:
        placed = False
        for i in range(len(array)):
            if array[i][1] < wrapped_net[1] and not placed:
                array.insert(i,wrapped_net)
                placed = True
        if not placed:
            array.append(wrapped_net)
    return array

# %%
# Creates a new population.
population = generate_base_wrapped_net_population(10)
generation = 0

# %%
# Loads a population from the disk.
hold = load_wrapped_net_population('eigthTrial')
population = hold[0]
generation = hold[1]

# %%
subject_popultaion_to_natural_selection(population,generation,name='eigthTrial',num_of_generations=10000,verbose_crawl=False)
# Out:
# Beginning Natural Selection For Generation : 10398 | Population Size : 143
# Generation 10398 High Score : 7 | Duration : 7.277798175811768 Secs
# Generation 10399 Bred
# Beginning Natural Selection For Generation : 10399 | Population Size : 143
# Generation 10399 High Score : 9 | Duration : 6.891412973403931 Secs
# Generation 10400 Bred
# Beginning Natural Selection For Generation : 10400 | Population Size : 45
# Generation 10400 High Score : 11 | Duration : 0.9478554725646973 Secs
# Generation 10401 Bred
# Beginning Natural Selection For Generation : 10401 | Population Size : 45
# Generation 10401 High Score : 5 | Duration : 0.6844794750213623 Secs
# Generation 10402 Bred
# Beginning Natural Selection For Generation : 10402 | Population Size : 45
# Generation 10402 High Score : 9 | Duration : 0.6393818855285645 Secs
# Generation 10403 Bred
# Beginning Natural Selection For Generation : 10403 | Population Size : 47
# Generation 10403 High Score : 14 | Duration : 0.5813498497009277 Secs
# Generation 10404 Bred
# Beginning Natural Selection For Generation : 10404 | Population Size : 47
# Generation 10404 High Score : 7 | Duration : 0.6339244842529297 Secs
# Generation 10405 Bred
# Beginning Natural Selection For Generation : 10405 | Population Size : 51
# Generation 10405 High Score : 6 | Duration : 0.6765367984771729 Secs
# Generation 10406 Bred
# Beginning Natural Selection For Generation : 10406 | Population Size : 51
# Generation 10406 High Score : 8 | Duration : 0.9527850151062012 Secs
# Generation 10407 Bred
# Beginning Natural Selection For Generation : 10407 | Population Size : 51
# Generation 10407 High Score : 5 | Duration : 1.0192761421203613 Secs
# Generation 10408 Bred
# Beginning Natural Selection For Generation : 10408 | Population Size : 51
# Generation 10408 High Score : 7 | Duration : 1.0158066749572754 Secs
# Generation 10409 Bred
# Beginning Natural Selection For Generation : 10409 | Population Size : 51
# Generation 10409 High Score : 11 | Duration : 0.8382408618927002 Secs
# Generation 10410 Bred
# Beginning Natural Selection For Generation : 10410 | Population Size : 51
# Generation 10410 High Score : 6 | Duration : 0.8719654083251953 Secs
# Generation 10411 Bred
# Beginning Natural Selection For Generation : 10411 | Population Size : 51
# Generation 10411 High Score : 5 | Duration : 0.768265962600708 Secs
# Generation 10412 Bred
# Beginning Natural Selection For Generation : 10412 | Population Size : 51
# Generation 10412 High Score : 4 | Duration : 1.0683844089508057 Secs
# Generation 10413 Bred
# Beginning Natural Selection For Generation : 10413 | Population Size : 55
# Generation 10413 High Score : 11 | Duration : 1.2409913539886475 Secs
# Generation 10414 Bred
# Beginning Natural Selection For Generation : 10414 | Population Size : 55
# Generation 10414 High Score : 5 | Duration : 0.687950849533081 Secs
# Generation 10415 Bred
# Beginning Natural Selection For Generation : 10415 | Population Size : 59
# Generation 10415 High Score : 6 | Duration : 0.9047524929046631 Secs
# Generation 10416 Bred
# Beginning Natural Selection For Generation : 10416 | Population Size : 63
# Generation 10416 High Score : 18 | Duration : 1.0207669734954834 Secs
# Generation 10417 Bred
# Beginning Natural Selection For Generation : 10417 | Population Size : 67
# Generation 10417 High Score : 3 | Duration : 0.9523520469665527 Secs
# Generation 10418 Bred
# Beginning Natural Selection For Generation : 10418 | Population Size : 67
# Generation 10418 High Score : 6 | Duration : 1.0391004085540771 Secs
# Generation 10419 Bred
# Beginning Natural Selection For Generation : 10419 | Population Size : 67
# Generation 10419 High Score : 6 | Duration : 1.6536610126495361 Secs
# Generation 10420 Bred
# Beginning Natural Selection For Generation : 10420 | Population Size : 67
# Generation 10420 High Score : 8 | Duration : 1.500936508178711 Secs
# Generation 10421 Bred
# Beginning Natural Selection For Generation : 10421 | Population Size : 71
# Generation 10421 High Score : 4 | Duration : 1.4056618213653564 Secs
# Generation 10422 Bred
# Beginning Natural Selection For Generation : 10422 | Population Size : 71
# Generation 10422 High Score : 8 | Duration : 1.830237627029419 Secs
# Generation 10423 Bred
# Beginning Natural Selection For Generation : 10423 | Population Size : 75
# Generation 10423 High Score : 10 | Duration : 1.407684564590454 Secs
# Generation 10424 Bred
# Beginning Natural Selection For Generation : 10424 | Population Size : 75
# Generation 10424 High Score : 5 | Duration : 1.4548070430755615 Secs
# Generation 10425 Bred
# Beginning Natural Selection For Generation : 10425 | Population Size : 75
# Generation 10425 High Score : 17 | Duration : 1.7411820888519287 Secs
# Generation 10426 Bred
# Beginning Natural Selection For Generation : 10426 | Population Size : 75
# Generation 10426 High Score : 8 | Duration : 1.7380213737487793 Secs
# Generation 10427 Bred
# Beginning Natural Selection For Generation : 10427 | Population Size : 75
# Generation 10427 High Score : 4 | Duration : 1.6903715133666992 Secs
# Generation 10428 Bred
# Beginning Natural Selection For Generation : 10428 | Population Size : 75
# Generation 10428 High Score : 4 | Duration : 1.6898658275604248 Secs
# Generation 10429 Bred
# Beginning Natural Selection For Generation : 10429 | Population Size : 75
# Generation 10429 High Score : 8 | Duration : 1.665107011795044 Secs
# Generation 10430 Bred
# Beginning Natural Selection For Generation : 10430 | Population Size : 79
# Generation 10430 High Score : 11 | Duration : 1.7112374305725098 Secs
# Generation 10431 Bred
# Beginning Natural Selection For Generation : 10431 | Population Size : 79
# Generation 10431 High Score : 6 | Duration : 1.7176451683044434 Secs
# Generation 10432 Bred
# Beginning Natural Selection For Generation : 10432 | Population Size : 79
# Generation 10432 High Score : 4 | Duration : 2.0469908714294434 Secs
# Generation 10433 Bred
# Beginning Natural Selection For Generation : 10433 | Population Size : 79
# Generation 10433 High Score : 5 | Duration : 1.5277197360992432 Secs
# Generation 10434 Bred
# Beginning Natural Selection For Generation : 10434 | Population Size : 79
# Generation 10434 High Score : 9 | Duration : 2.0807178020477295 Secs
# Generation 10435 Bred
# Beginning Natural Selection For Generation : 10435 | Population Size : 79
# Generation 10435 High Score : 6 | Duration : 1.848587989807129 Secs
# Generation 10436 Bred
# Beginning Natural Selection For Generation : 10436 | Population Size : 79
# Generation 10436 High Score : 9 | Duration : 1.8143646717071533 Secs
# Generation 10437 Bred
# Beginning Natural Selection For Generation : 10437 | Population Size : 83
# Generation 10437 High Score : 6 | Duration : 2.064845561981201 Secs
# Generation 10438 Bred
# Beginning Natural Selection For Generation : 10438 | Population Size : 83
# Generation 10438 High Score : 11 | Duration : 1.4934492111206055 Secs
# Generation 10439 Bred
# Beginning Natural Selection For Generation : 10439 | Population Size : 83
# Generation 10439 High Score : 7 | Duration : 1.9185657501220703 Secs
# Generation 10440 Bred
# Beginning Natural Selection For Generation : 10440 | Population Size : 83
# Generation 10440 High Score : 8 | Duration : 2.118455410003662 Secs
# Generation 10441 Bred
# Beginning Natural Selection For Generation : 10441 | Population Size : 83
# Generation 10441 High Score : 5 | Duration : 2.391195774078369 Secs
# Generation 10442 Bred
# Beginning Natural Selection For Generation : 10442 | Population Size : 87
# Generation 10442 High Score : 13 | Duration : 2.126831293106079 Secs
# Generation 10443 Bred
# Beginning Natural Selection For Generation : 10443 | Population Size : 87
# Generation 10443 High Score : 8 | Duration : 2.1779346466064453 Secs
# Generation 10444 Bred
# Beginning Natural Selection For Generation : 10444 | Population Size : 87
# Generation 10444 High Score : 8 | Duration : 2.2587714195251465 Secs
# Generation 10445 Bred
# Beginning Natural Selection For Generation : 10445 | Population Size : 91
# Generation 10445 High Score : 6 | Duration : 2.951204776763916 Secs
# Generation 10446 Bred
# Beginning Natural Selection For Generation : 10446 | Population Size : 91
# Generation 10446 High Score : 6 | Duration : 2.367943286895752 Secs
# Generation 10447 Bred
# Beginning Natural Selection For Generation : 10447 | Population Size : 91
# Generation 10447 High Score : 8 | Duration : 2.8684048652648926 Secs
# Generation 10448 Bred
# Beginning Natural Selection For Generation : 10448 | Population Size : 91
# Generation 10448 High Score : 6 | Duration : 2.7835028171539307 Secs
# Generation 10449 Bred
# Beginning Natural Selection For Generation : 10449 | Population Size : 91
# Generation 10449 High Score : 8 | Duration : 3.063328504562378 Secs
# Generation 10450 Bred
# Beginning Natural Selection For Generation : 10450 | Population Size : 91
# Generation 10450 High Score : 6 | Duration : 2.887251138687134 Secs
# Generation 10451 Bred
# Beginning Natural Selection For Generation : 10451 | Population Size : 91
# Generation 10451 High Score : 8 | Duration : 2.6148669719696045 Secs
# Generation 10452 Bred
# Beginning Natural Selection For Generation : 10452 | Population Size : 91
# Generation 10452 High Score : 8 | Duration : 2.783548355102539 Secs
# Generation 10453 Bred
# Beginning Natural Selection For Generation : 10453 | Population Size : 91
# Generation 10453 High Score : 8 | Duration : 3.160508871078491 Secs
# Generation 10454 Bred
# Beginning Natural Selection For Generation : 10454 | Population Size : 91
# Generation 10454 High Score : 9 | Duration : 2.6600449085235596 Secs
# Generation 10455 Bred
# Beginning Natural Selection For Generation : 10455 | Population Size : 91
# Generation 10455 High Score : 12 | Duration : 2.572739601135254 Secs
# Generation 10456 Bred
# Beginning Natural Selection For Generation : 10456 | Population Size : 91
# Generation 10456 High Score : 12 | Duration : 2.6342175006866455 Secs
# Generation 10457 Bred
# Beginning Natural Selection For Generation : 10457 | Population Size : 91
# Generation 10457 High Score : 6 | Duration : 2.3857967853546143 Secs
# Generation 10458 Bred
# Beginning Natural Selection For Generation : 10458 | Population Size : 91
# Generation 10458 High Score : 6 | Duration : 2.4636237621307373 Secs
# Generation 10459 Bred
# Beginning Natural Selection For Generation : 10459 | Population Size : 91
# Generation 10459 High Score : 9 | Duration : 2.328176975250244 Secs
# Generation 10460 Bred
# Beginning Natural Selection For Generation : 10460 | Population Size : 91
# Generation 10460 High Score : 9 | Duration : 2.054468870162964 Secs
# Generation 10461 Bred
# Beginning Natural Selection For Generation : 10461 | Population Size : 91
# Generation 10461 High Score : 6 | Duration : 2.075718641281128 Secs
# Generation 10462 Bred
# Beginning Natural Selection For Generation : 10462 | Population Size : 91
# Generation 10462 High Score : 6 | Duration : 2.17942214012146 Secs
# Generation 10463 Bred
# Beginning Natural Selection For Generation : 10463 | Population Size : 91
# Generation 10463 High Score : 12 | Duration : 2.768171787261963 Secs
# Generation 10464 Bred
# Beginning Natural Selection For Generation : 10464 | Population Size : 91
# Generation 10464 High Score : 9 | Duration : 2.7230753898620605 Secs
# Generation 10465 Bred
# Beginning Natural Selection For Generation : 10465 | Population Size : 91
# Generation 10465 High Score : 8 | Duration : 2.600069046020508 Secs
# Generation 10466 Bred
# Beginning Natural Selection For Generation : 10466 | Population Size : 91
# Generation 10466 High Score : 15 | Duration : 2.6615264415740967 Secs
# Generation 10467 Bred
# Beginning Natural Selection For Generation : 10467 | Population Size : 91
# Generation 10467 High Score : 7 | Duration : 2.6273083686828613 Secs
# Generation 10468 Bred
# Beginning Natural Selection For Generation : 10468 | Population Size : 95
# Generation 10468 High Score : 11 | Duration : 3.4779090881347656 Secs
# Generation 10469 Bred
# Beginning Natural Selection For Generation : 10469 | Population Size : 95
# Generation 10469 High Score : 8 | Duration : 2.541451930999756 Secs
# Generation 10470 Bred
# Beginning Natural Selection For Generation : 10470 | Population Size : 95
# Generation 10470 High Score : 4 | Duration : 2.9170196056365967 Secs
# Generation 10471 Bred
# Beginning Natural Selection For Generation : 10471 | Population Size : 95
# Generation 10471 High Score : 8 | Duration : 2.498387575149536 Secs
# Generation 10472 Bred
# Beginning Natural Selection For Generation : 10472 | Population Size : 95
# Generation 10472 High Score : 10 | Duration : 2.8390965461730957 Secs
# Generation 10473 Bred
# Beginning Natural Selection For Generation : 10473 | Population Size : 95
# Generation 10473 High Score : 6 | Duration : 2.947747230529785 Secs
# Generation 10474 Bred
# Beginning Natural Selection For Generation : 10474 | Population Size : 99
# Generation 10474 High Score : 18 | Duration : 2.1947972774505615 Secs
# Generation 10475 Bred
# Beginning Natural Selection For Generation : 10475 | Population Size : 99
# Generation 10475 High Score : 9 | Duration : 2.6273488998413086 Secs
# Generation 10476 Bred
# Beginning Natural Selection For Generation : 10476 | Population Size : 99
# Generation 10476 High Score : 13 | Duration : 2.733482837677002 Secs
# Generation 10477 Bred
# Beginning Natural Selection For Generation : 10477 | Population Size : 99
# Generation 10477 High Score : 13 | Duration : 3.1957569122314453 Secs
# Generation 10478 Bred
# Beginning Natural Selection For Generation : 10478 | Population Size : 99
# Generation 10478 High Score : 9 | Duration : 2.9720728397369385 Secs
# Generation 10479 Bred
# Beginning Natural Selection For Generation : 10479 | Population Size : 99
# Generation 10479 High Score : 7 | Duration : 2.8262033462524414 Secs
# Generation 10480 Bred
# Beginning Natural Selection For Generation : 10480 | Population Size : 99
# Generation 10480 High Score : 14 | Duration : 2.817316770553589 Secs
# Generation 10481 Bred
# Beginning Natural Selection For Generation : 10481 | Population Size : 99
# Generation 10481 High Score : 9 | Duration : 2.8515002727508545 Secs
# Generation 10482 Bred
# Beginning Natural Selection For Generation : 10482 | Population Size : 99
# Generation 10482 High Score : 5 | Duration : 2.636235237121582 Secs
# Generation 10483 Bred
# Beginning Natural Selection For Generation : 10483 | Population Size : 99
# Generation 10483 High Score : 6 | Duration : 3.2409024238586426 Secs
# Generation 10484 Bred
# Beginning Natural Selection For Generation : 10484 | Population Size : 99
# Generation 10484 High Score : 11 | Duration : 2.5920910835266113 Secs
# Generation 10485 Bred
# Beginning Natural Selection For Generation : 10485 | Population Size : 99
# Generation 10485 High Score : 6 | Duration : 3.274089813232422 Secs
# Generation 10486 Bred
# Beginning Natural Selection For Generation : 10486 | Population Size : 99
# Generation 10486 High Score : 10 | Duration : 2.975001096725464 Secs
# Generation 10487 Bred
# Beginning Natural Selection For Generation : 10487 | Population Size : 99
# Generation 10487 High Score : 10 | Duration : 3.124833822250366 Secs
# Generation 10488 Bred
# Beginning Natural Selection For Generation : 10488 | Population Size : 99
# Generation 10488 High Score : 9 | Duration : 3.1248385906219482 Secs
# Generation 10489 Bred
# Beginning Natural Selection For Generation : 10489 | Population Size : 99
# Generation 10489 High Score : 12 | Duration : 3.2567336559295654 Secs
# Generation 10490 Bred
# Beginning Natural Selection For Generation : 10490 | Population Size : 99
# Generation 10490 High Score : 10 | Duration : 2.858938217163086 Secs
# Generation 10491 Bred
# Beginning Natural Selection For Generation : 10491 | Population Size : 99
# Generation 10491 High Score : 5 | Duration : 3.084167957305908 Secs
# Generation 10492 Bred
# Beginning Natural Selection For Generation : 10492 | Population Size : 99
# Generation 10492 High Score : 7 | Duration : 2.6809239387512207 Secs
# Generation 10493 Bred
# Beginning Natural Selection For Generation : 10493 | Population Size : 99
# Generation 10493 High Score : 11 | Duration : 2.930858612060547 Secs
# Generation 10494 Bred
# Beginning Natural Selection For Generation : 10494 | Population Size : 99
# Generation 10494 High Score : 8 | Duration : 2.6471519470214844 Secs
# Generation 10495 Bred
# Beginning Natural Selection For Generation : 10495 | Population Size : 99
# Generation 10495 High Score : 8 | Duration : 3.3137707710266113 Secs
# Generation 10496 Bred
# Beginning Natural Selection For Generation : 10496 | Population Size : 99
# Generation 10496 High Score : 14 | Duration : 2.9889307022094727 Secs
# Generation 10497 Bred
# Beginning Natural Selection For Generation : 10497 | Population Size : 99
# Generation 10497 High Score : 10 | Duration : 3.2929391860961914 Secs
# Generation 10498 Bred
# Beginning Natural Selection For Generation : 10498 | Population Size : 103
# Generation 10498 High Score : 7 | Duration : 3.0514261722564697 Secs
# Generation 10499 Bred
# Beginning Natural Selection For Generation : 10499 | Population Size : 103
# Generation 10499 High Score : 16 | Duration : 2.8832404613494873 Secs
# Generation 10500 Bred
# Beginning Natural Selection For Generation : 10500 | Population Size : 103
# Generation 10500 High Score : 7 | Duration : 3.25822114944458 Secs
# Generation 10501 Bred
# Beginning Natural Selection For Generation : 10501 | Population Size : 104
# Generation 10501 High Score : 8 | Duration : 2.634702205657959 Secs
# Generation 10502 Bred
# Beginning Natural Selection For Generation : 10502 | Population Size : 104
# Generation 10502 High Score : 8 | Duration : 3.4000637531280518 Secs
# Generation 10503 Bred
# Beginning Natural Selection For Generation : 10503 | Population Size : 104
# Generation 10503 High Score : 9 | Duration : 3.562823534011841 Secs
# Generation 10504 Bred
# Beginning Natural Selection For Generation : 10504 | Population Size : 104
# Generation 10504 High Score : 6 | Duration : 3.5454025268554688 Secs
# Generation 10505 Bred
# Beginning Natural Selection For Generation : 10505 | Population Size : 104
# Generation 10505 High Score : 9 | Duration : 3.806333303451538 Secs
# Generation 10506 Bred
# Beginning Natural Selection For Generation : 10506 | Population Size : 104
# Generation 10506 High Score : 9 | Duration : 3.2507293224334717 Secs
# Generation 10507 Bred
# Beginning Natural Selection For Generation : 10507 | Population Size : 104
# Generation 10507 High Score : 7 | Duration : 3.2368922233581543 Secs
# Generation 10508 Bred
# Beginning Natural Selection For Generation : 10508 | Population Size : 104
# Generation 10508 High Score : 8 | Duration : 3.778067111968994 Secs
# Generation 10509 Bred
# Beginning Natural Selection For Generation : 10509 | Population Size : 104
# Generation 10509 High Score : 6 | Duration : 3.5563151836395264 Secs
# Generation 10510 Bred
# Beginning Natural Selection For Generation : 10510 | Population Size : 104
# Generation 10510 High Score : 8 | Duration : 3.7189993858337402 Secs
# Generation 10511 Bred
# Beginning Natural Selection For Generation : 10511 | Population Size : 104
# Generation 10511 High Score : 7 | Duration : 3.407017946243286 Secs
# Generation 10512 Bred
# Beginning Natural Selection For Generation : 10512 | Population Size : 104
# Generation 10512 High Score : 7 | Duration : 2.391235828399658 Secs
# Generation 10513 Bred
# Beginning Natural Selection For Generation : 10513 | Population Size : 104
# Generation 10513 High Score : 6 | Duration : 3.456575632095337 Secs
# Generation 10514 Bred
# Beginning Natural Selection For Generation : 10514 | Population Size : 104
# Generation 10514 High Score : 9 | Duration : 3.363816022872925 Secs
# Generation 10515 Bred
# Beginning Natural Selection For Generation : 10515 | Population Size : 104
# Generation 10515 High Score : 14 | Duration : 3.158027172088623 Secs
# Generation 10516 Bred
# Beginning Natural Selection For Generation : 10516 | Population Size : 104
# Generation 10516 High Score : 7 | Duration : 3.7765817642211914 Secs
# Generation 10517 Bred
# Beginning Natural Selection For Generation : 10517 | Population Size : 104
# Generation 10517 High Score : 9 | Duration : 3.3286516666412354 Secs
# Generation 10518 Bred
# Beginning Natural Selection For Generation : 10518 | Population Size : 104
# Generation 10518 High Score : 9 | Duration : 3.143597364425659 Secs
# Generation 10519 Bred
# Beginning Natural Selection For Generation : 10519 | Population Size : 104
# Generation 10519 High Score : 7 | Duration : 3.6987040042877197 Secs
# Generation 10520 Bred
# Beginning Natural Selection For Generation : 10520 | Population Size : 104
# Generation 10520 High Score : 7 | Duration : 3.4680278301239014 Secs
# Generation 10521 Bred
# Beginning Natural Selection For Generation : 10521 | Population Size : 104
# Generation 10521 High Score : 8 | Duration : 3.146620512008667 Secs
# Generation 10522 Bred
# Beginning Natural Selection For Generation : 10522 | Population Size : 104
# Generation 10522 High Score : 7 | Duration : 3.433347463607788 Secs
# Generation 10523 Bred
# Beginning Natural Selection For Generation : 10523 | Population Size : 104
# Generation 10523 High Score : 5 | Duration : 3.2408597469329834 Secs
# Generation 10524 Bred
# Beginning Natural Selection For Generation : 10524 | Population Size : 104
# Generation 10524 High Score : 7 | Duration : 2.9536795616149902 Secs
# Generation 10525 Bred
# Beginning Natural Selection For Generation : 10525 | Population Size : 104
# Generation 10525 High Score : 6 | Duration : 3.002732753753662 Secs
# Generation 10526 Bred
# Beginning Natural Selection For Generation : 10526 | Population Size : 104
# Generation 10526 High Score : 6 | Duration : 3.2075769901275635 Secs
# Generation 10527 Bred
# Beginning Natural Selection For Generation : 10527 | Population Size : 104
# Generation 10527 High Score : 8 | Duration : 2.888249635696411 Secs
# Generation 10528 Bred
# Beginning Natural Selection For Generation : 10528 | Population Size : 104
# Generation 10528 High Score : 9 | Duration : 3.276068925857544 Secs
# Generation 10529 Bred
# Beginning Natural Selection For Generation : 10529 | Population Size : 107
# Generation 10529 High Score : 15 | Duration : 2.9542131423950195 Secs
# Generation 10530 Bred
# Beginning Natural Selection For Generation : 10530 | Population Size : 107
# Generation 10530 High Score : 8 | Duration : 2.6169323921203613 Secs
# Generation 10531 Bred
# Beginning Natural Selection For Generation : 10531 | Population Size : 107
# Generation 10531 High Score : 6 | Duration : 3.3484866619110107 Secs
# Generation 10532 Bred
# Beginning Natural Selection For Generation : 10532 | Population Size : 111
# Generation 10532 High Score : 8 | Duration : 3.5692028999328613 Secs
# Generation 10533 Bred
# Beginning Natural Selection For Generation : 10533 | Population Size : 115
# Generation 10533 High Score : 5 | Duration : 4.607285022735596 Secs
# Generation 10534 Bred
# Beginning Natural Selection For Generation : 10534 | Population Size : 119
# Generation 10534 High Score : 5 | Duration : 3.9774587154388428 Secs
# Generation 10535 Bred
# Beginning Natural Selection For Generation : 10535 | Population Size : 123
# Generation 10535 High Score : 10 | Duration : 3.508655071258545 Secs
# Generation 10536 Bred
# Beginning Natural Selection For Generation : 10536 | Population Size : 123
# Generation 10536 High Score : 9 | Duration : 5.144047975540161 Secs
# Generation 10537 Bred
# Beginning Natural Selection For Generation : 10537 | Population Size : 123
# Generation 10537 High Score : 16 | Duration : 4.117290496826172 Secs
# Generation 10538 Bred
# Beginning Natural Selection For Generation : 10538 | Population Size : 123
# Generation 10538 High Score : 9 | Duration : 4.527023792266846 Secs
# Generation 10539 Bred
# Beginning Natural Selection For Generation : 10539 | Population Size : 123
# Generation 10539 High Score : 6 | Duration : 4.876665353775024 Secs
# Generation 10540 Bred
# Beginning Natural Selection For Generation : 10540 | Population Size : 123
# Generation 10540 High Score : 6 | Duration : 4.950025796890259 Secs
# Generation 10541 Bred
# Beginning Natural Selection For Generation : 10541 | Population Size : 123
# Generation 10541 High Score : 7 | Duration : 4.277498245239258 Secs
# Generation 10542 Bred
# Beginning Natural Selection For Generation : 10542 | Population Size : 123
# Generation 10542 High Score : 7 | Duration : 5.153916835784912 Secs
# Generation 10543 Bred
# Beginning Natural Selection For Generation : 10543 | Population Size : 123
# Generation 10543 High Score : 4 | Duration : 4.355905055999756 Secs
# Generation 10544 Bred
# Beginning Natural Selection For Generation : 10544 | Population Size : 123
# Generation 10544 High Score : 15 | Duration : 3.616867780685425 Secs
# Generation 10545 Bred
# Beginning Natural Selection For Generation : 10545 | Population Size : 123
# Generation 10545 High Score : 11 | Duration : 4.392113924026489 Secs
# Generation 10546 Bred
# Beginning Natural Selection For Generation : 10546 | Population Size : 123
# Generation 10546 High Score : 5 | Duration : 4.099477052688599 Secs
# Generation 10547 Bred
# Beginning Natural Selection For Generation : 10547 | Population Size : 123
# Generation 10547 High Score : 14 | Duration : 3.726978302001953 Secs
# Generation 10548 Bred
# Beginning Natural Selection For Generation : 10548 | Population Size : 123
# Generation 10548 High Score : 14 | Duration : 4.497223377227783 Secs
# Generation 10549 Bred
# Beginning Natural Selection For Generation : 10549 | Population Size : 123
# Generation 10549 High Score : 9 | Duration : 4.6594579219818115 Secs
# Generation 10550 Bred
# Beginning Natural Selection For Generation : 10550 | Population Size : 123
# Generation 10550 High Score : 9 | Duration : 4.70459508895874 Secs
# Generation 10551 Bred
# Beginning Natural Selection For Generation : 10551 | Population Size : 123
# Generation 10551 High Score : 11 | Duration : 4.5071446895599365 Secs
# Generation 10552 Bred
# Beginning Natural Selection For Generation : 10552 | Population Size : 123
# Generation 10552 High Score : 7 | Duration : 4.225914716720581 Secs
# Generation 10553 Bred
# Beginning Natural Selection For Generation : 10553 | Population Size : 123
# Generation 10553 High Score : 10 | Duration : 5.087464094161987 Secs
# Generation 10554 Bred
# Beginning Natural Selection For Generation : 10554 | Population Size : 123
# Generation 10554 High Score : 7 | Duration : 5.426272392272949 Secs
# Generation 10555 Bred
# Beginning Natural Selection For Generation : 10555 | Population Size : 123
# Generation 10555 High Score : 7 | Duration : 4.7234416007995605 Secs
# Generation 10556 Bred
# Beginning Natural Selection For Generation : 10556 | Population Size : 123
# Generation 10556 High Score : 9 | Duration : 4.632618427276611 Secs
# Generation 10557 Bred
# Beginning Natural Selection For Generation : 10557 | Population Size : 123
# Generation 10557 High Score : 9 | Duration : 5.06758189201355 Secs
# Generation 10558 Bred
# Beginning Natural Selection For Generation : 10558 | Population Size : 123
# Generation 10558 High Score : 8 | Duration : 5.235809087753296 Secs
# Generation 10559 Bred
# Beginning Natural Selection For Generation : 10559 | Population Size : 127
# Generation 10559 High Score : 8 | Duration : 4.427825450897217 Secs
# Generation 10560 Bred
# Beginning Natural Selection For Generation : 10560 | Population Size : 127
# Generation 10560 High Score : 11 | Duration : 5.257098197937012 Secs
# Generation 10561 Bred
# Beginning Natural Selection For Generation : 10561 | Population Size : 128
# Generation 10561 High Score : 6 | Duration : 4.522064447402954 Secs
# Generation 10562 Bred
# Beginning Natural Selection For Generation : 10562 | Population Size : 128
# Generation 10562 High Score : 8 | Duration : 5.730815410614014 Secs
# Generation 10563 Bred
# Beginning Natural Selection For Generation : 10563 | Population Size : 128
# Generation 10563 High Score : 14 | Duration : 5.790296792984009 Secs
# Generation 10564 Bred
# Beginning Natural Selection For Generation : 10564 | Population Size : 128
# Generation 10564 High Score : 7 | Duration : 4.9604880809783936 Secs
# Generation 10565 Bred
# Beginning Natural Selection For Generation : 10565 | Population Size : 128
# Generation 10565 High Score : 9 | Duration : 5.713954925537109 Secs
# Generation 10566 Bred
# Beginning Natural Selection For Generation : 10566 | Population Size : 128
# Generation 10566 High Score : 7 | Duration : 4.6783061027526855 Secs
# Generation 10567 Bred
# Beginning Natural Selection For Generation : 10567 | Population Size : 128
# Generation 10567 High Score : 10 | Duration : 4.562201976776123 Secs
# Generation 10568 Bred
# Beginning Natural Selection For Generation : 10568 | Population Size : 128
# Generation 10568 High Score : 8 | Duration : 5.413379907608032 Secs
# Generation 10569 Bred
# Beginning Natural Selection For Generation : 10569 | Population Size : 128
# Generation 10569 High Score : 7 | Duration : 5.031914949417114 Secs
# Generation 10570 Bred
# Beginning Natural Selection For Generation : 10570 | Population Size : 128
# Generation 10570 High Score : 7 | Duration : 4.577069044113159 Secs
# Generation 10571 Bred
# Beginning Natural Selection For Generation : 10571 | Population Size : 128
# Generation 10571 High Score : 6 | Duration : 5.607808828353882 Secs
# Generation 10572 Bred
# Beginning Natural Selection For Generation : 10572 | Population Size : 128
# Generation 10572 High Score : 7 | Duration : 4.994713306427002 Secs
# Generation 10573 Bred
# Beginning Natural Selection For Generation : 10573 | Population Size : 128
# Generation 10573 High Score : 9 | Duration : 6.1776697635650635 Secs
# Generation 10574 Bred
# Beginning Natural Selection For Generation : 10574 | Population Size : 128
# Generation 10574 High Score : 5 | Duration : 5.998080492019653 Secs
# Generation 10575 Bred
# Beginning Natural Selection For Generation : 10575 | Population Size : 131
# Generation 10575 High Score : 9 | Duration : 4.425341844558716 Secs
# Generation 10576 Bred
# Beginning Natural Selection For Generation : 10576 | Population Size : 131
# Generation 10576 High Score : 19 | Duration : 5.548787832260132 Secs
# Generation 10577 Bred
# Beginning Natural Selection For Generation : 10577 | Population Size : 131
# Generation 10577 High Score : 10 | Duration : 4.847852468490601 Secs
# Generation 10578 Bred
# Beginning Natural Selection For Generation : 10578 | Population Size : 131
# Generation 10578 High Score : 6 | Duration : 5.307689905166626 Secs
# Generation 10579 Bred
# Beginning Natural Selection For Generation : 10579 | Population Size : 131
# Generation 10579 High Score : 7 | Duration : 5.27792501449585 Secs
# Generation 10580 Bred
# Beginning Natural Selection For Generation : 10580 | Population Size : 131
# Generation 10580 High Score : 8 | Duration : 4.747248411178589 Secs
# Generation 10581 Bred
# Beginning Natural Selection For Generation : 10581 | Population Size : 131
# Generation 10581 High Score : 8 | Duration : 4.915889739990234 Secs
# Generation 10582 Bred
# Beginning Natural Selection For Generation : 10582 | Population Size : 131
# Generation 10582 High Score : 11 | Duration : 5.211503982543945 Secs
# Generation 10583 Bred
# Beginning Natural Selection For Generation : 10583 | Population Size : 131
# Generation 10583 High Score : 7 | Duration : 5.461448431015015 Secs
# Generation 10584 Bred
# Beginning Natural Selection For Generation : 10584 | Population Size : 135
# Generation 10584 High Score : 9 | Duration : 4.879193067550659 Secs
# Generation 10585 Bred
# Beginning Natural Selection For Generation : 10585 | Population Size : 135
# Generation 10585 High Score : 8 | Duration : 5.129668712615967 Secs
# Generation 10586 Bred
# Beginning Natural Selection For Generation : 10586 | Population Size : 135
# Generation 10586 High Score : 7 | Duration : 5.562633037567139 Secs
# Generation 10587 Bred
# Beginning Natural Selection For Generation : 10587 | Population Size : 135
# Generation 10587 High Score : 8 | Duration : 5.599292516708374 Secs
# Generation 10588 Bred
# Beginning Natural Selection For Generation : 10588 | Population Size : 135
# Generation 10588 High Score : 10 | Duration : 6.096864461898804 Secs
# Generation 10589 Bred
# Beginning Natural Selection For Generation : 10589 | Population Size : 135
# Generation 10589 High Score : 5 | Duration : 6.8706231117248535 Secs
# Generation 10590 Bred
# Beginning Natural Selection For Generation : 10590 | Population Size : 135
# Generation 10590 High Score : 9 | Duration : 6.057659149169922 Secs
# Generation 10591 Bred
# Beginning Natural Selection For Generation : 10591 | Population Size : 135
# Generation 10591 High Score : 9 | Duration : 6.470357179641724 Secs
# Generation 10592 Bred
# Beginning Natural Selection For Generation : 10592 | Population Size : 135
# Generation 10592 High Score : 11 | Duration : 5.863168716430664 Secs
# Generation 10593 Bred
# Beginning Natural Selection For Generation : 10593 | Population Size : 135
# Generation 10593 High Score : 9 | Duration : 5.322610855102539 Secs
# Generation 10594 Bred
# Beginning Natural Selection For Generation : 10594 | Population Size : 135
# Generation 10594 High Score : 10 | Duration : 5.583962917327881 Secs
# Generation 10595 Bred
# Beginning Natural Selection For Generation : 10595 | Population Size : 135
# Generation 10595 High Score : 8 | Duration : 5.074571847915649 Secs
# Generation 10596 Bred
# Beginning Natural Selection For Generation : 10596 | Population Size : 135
# Generation 10596 High Score : 8 | Duration : 5.159923791885376 Secs
# Generation 10597 Bred
# Beginning Natural Selection For Generation : 10597 | Population Size : 135
# Generation 10597 High Score : 8 | Duration : 5.200538158416748 Secs
# Generation 10598 Bred
# Beginning Natural Selection For Generation : 10598 | Population Size : 135
# Generation 10598 High Score : 10 | Duration : 3.9645626544952393 Secs
# Generation 10599 Bred
# Beginning Natural Selection For Generation : 10599 | Population Size : 135
# Generation 10599 High Score : 11 | Duration : 5.35981297492981 Secs
# Generation 10600 Bred
# Beginning Natural Selection For Generation : 10600 | Population Size : 45
# Generation 10600 High Score : 7 | Duration : 0.6169805526733398 Secs
# Generation 10601 Bred
# Beginning Natural Selection For Generation : 10601 | Population Size : 45
# Generation 10601 High Score : 6 | Duration : 0.7618086338043213 Secs
# Generation 10602 Bred
# Beginning Natural Selection For Generation : 10602 | Population Size : 45
# Generation 10602 High Score : 5 | Duration : 0.7341189384460449 Secs
# Generation 10603 Bred
# Beginning Natural Selection For Generation : 10603 | Population Size : 45
# Generation 10603 High Score : 8 | Duration : 0.6893894672393799 Secs
# Generation 10604 Bred
# Beginning Natural Selection For Generation : 10604 | Population Size : 45
# Generation 10604 High Score : 6 | Duration : 0.6264116764068604 Secs
# Generation 10605 Bred
# Beginning Natural Selection For Generation : 10605 | Population Size : 45
# Generation 10605 High Score : 8 | Duration : 0.6616506576538086 Secs
# Generation 10606 Bred
# Beginning Natural Selection For Generation : 10606 | Population Size : 45
# Generation 10606 High Score : 4 | Duration : 0.7018406391143799 Secs
# Generation 10607 Bred
# Beginning Natural Selection For Generation : 10607 | Population Size : 45
# Generation 10607 High Score : 6 | Duration : 0.6031363010406494 Secs
# Generation 10608 Bred
# Beginning Natural Selection For Generation : 10608 | Population Size : 48
# Generation 10608 High Score : 4 | Duration : 0.7098221778869629 Secs
# Generation 10609 Bred
# Beginning Natural Selection For Generation : 10609 | Population Size : 51
# Generation 10609 High Score : 15 | Duration : 0.6130125522613525 Secs
# Generation 10610 Bred
# Beginning Natural Selection For Generation : 10610 | Population Size : 52
# Generation 10610 High Score : 11 | Duration : 0.8183975219726562 Secs
# Generation 10611 Bred
# Beginning Natural Selection For Generation : 10611 | Population Size : 52
# Generation 10611 High Score : 10 | Duration : 0.7975671291351318 Secs
# Generation 10612 Bred
# Beginning Natural Selection For Generation : 10612 | Population Size : 52
# Generation 10612 High Score : 11 | Duration : 0.915614128112793 Secs
# Generation 10613 Bred
# Beginning Natural Selection For Generation : 10613 | Population Size : 52
# Generation 10613 High Score : 7 | Duration : 0.8803472518920898 Secs
# Generation 10614 Bred
# Beginning Natural Selection For Generation : 10614 | Population Size : 52
# Generation 10614 High Score : 6 | Duration : 0.9131348133087158 Secs
# Generation 10615 Bred
# Beginning Natural Selection For Generation : 10615 | Population Size : 52
# Generation 10615 High Score : 4 | Duration : 0.949838399887085 Secs
# Generation 10616 Bred
# Beginning Natural Selection For Generation : 10616 | Population Size : 52
# Generation 10616 High Score : 10 | Duration : 0.6364080905914307 Secs
# Generation 10617 Bred
# Beginning Natural Selection For Generation : 10617 | Population Size : 55
# Generation 10617 High Score : 7 | Duration : 0.7529687881469727 Secs
# Generation 10618 Bred
# Beginning Natural Selection For Generation : 10618 | Population Size : 55
# Generation 10618 High Score : 4 | Duration : 0.8278219699859619 Secs
# Generation 10619 Bred
# Beginning Natural Selection For Generation : 10619 | Population Size : 55
# Generation 10619 High Score : 8 | Duration : 0.856132984161377 Secs
# Generation 10620 Bred
# Beginning Natural Selection For Generation : 10620 | Population Size : 55
# Generation 10620 High Score : 4 | Duration : 0.9389157295227051 Secs
# Generation 10621 Bred
# Beginning Natural Selection For Generation : 10621 | Population Size : 59
# Generation 10621 High Score : 11 | Duration : 1.059950590133667 Secs
# Generation 10622 Bred
# Beginning Natural Selection For Generation : 10622 | Population Size : 59
# Generation 10622 High Score : 4 | Duration : 1.0942192077636719 Secs
# Generation 10623 Bred
# Beginning Natural Selection For Generation : 10623 | Population Size : 59
# Generation 10623 High Score : 12 | Duration : 0.8794522285461426 Secs
# Generation 10624 Bred
# Beginning Natural Selection For Generation : 10624 | Population Size : 59
# Generation 10624 High Score : 4 | Duration : 1.127946138381958 Secs
# Generation 10625 Bred
# Beginning Natural Selection For Generation : 10625 | Population Size : 59
# Generation 10625 High Score : 5 | Duration : 0.8943262100219727 Secs
# Generation 10626 Bred
# Beginning Natural Selection For Generation : 10626 | Population Size : 63
# Generation 10626 High Score : 3 | Duration : 0.8739910125732422 Secs
# Generation 10627 Bred
# Beginning Natural Selection For Generation : 10627 | Population Size : 63
# Generation 10627 High Score : 7 | Duration : 1.2970373630523682 Secs
# Generation 10628 Bred
# Beginning Natural Selection For Generation : 10628 | Population Size : 63
# Generation 10628 High Score : 7 | Duration : 1.1903929710388184 Secs
# Generation 10629 Bred
# Beginning Natural Selection For Generation : 10629 | Population Size : 63
# Generation 10629 High Score : 7 | Duration : 1.317373514175415 Secs
# Generation 10630 Bred
# Beginning Natural Selection For Generation : 10630 | Population Size : 63
# Generation 10630 High Score : 8 | Duration : 1.3888368606567383 Secs
# Generation 10631 Bred
# Beginning Natural Selection For Generation : 10631 | Population Size : 63
# Generation 10631 High Score : 7 | Duration : 1.5009384155273438 Secs
# Generation 10632 Bred
# Beginning Natural Selection For Generation : 10632 | Population Size : 63
# Generation 10632 High Score : 8 | Duration : 1.2628514766693115 Secs
# Generation 10633 Bred
# Beginning Natural Selection For Generation : 10633 | Population Size : 63
# Generation 10633 High Score : 5 | Duration : 1.1651020050048828 Secs
# Generation 10634 Bred
# Beginning Natural Selection For Generation : 10634 | Population Size : 63
# Generation 10634 High Score : 15 | Duration : 1.4300062656402588 Secs
# Generation 10635 Bred
# Beginning Natural Selection For Generation : 10635 | Population Size : 63
# Generation 10635 High Score : 6 | Duration : 1.4646899700164795 Secs
# Generation 10636 Bred
# Beginning Natural Selection For Generation : 10636 | Population Size : 63
# Generation 10636 High Score : 6 | Duration : 1.3987183570861816 Secs
# Generation 10637 Bred
# Beginning Natural Selection For Generation : 10637 | Population Size : 63
# Generation 10637 High Score : 6 | Duration : 1.403181552886963 Secs
# Generation 10638 Bred
# Beginning Natural Selection For Generation : 10638 | Population Size : 64
# Generation 10638 High Score : 4 | Duration : 1.3670144081115723 Secs
# Generation 10639 Bred
# Beginning Natural Selection For Generation : 10639 | Population Size : 64
# Generation 10639 High Score : 8 | Duration : 1.4503018856048584 Secs
# Generation 10640 Bred
# Beginning Natural Selection For Generation : 10640 | Population Size : 64
# Generation 10640 High Score : 7 | Duration : 1.4155809879302979 Secs
# Generation 10641 Bred
# Beginning Natural Selection For Generation : 10641 | Population Size : 64
# Generation 10641 High Score : 6 | Duration : 1.19887375831604 Secs
# Generation 10642 Bred
# Beginning Natural Selection For Generation : 10642 | Population Size : 64
# Generation 10642 High Score : 9 | Duration : 1.289130449295044 Secs
# Generation 10643 Bred
# Beginning Natural Selection For Generation : 10643 | Population Size : 64
# Generation 10643 High Score : 11 | Duration : 1.396238088607788 Secs
# Generation 10644 Bred
# Beginning Natural Selection For Generation : 10644 | Population Size : 64
# Generation 10644 High Score : 5 | Duration : 1.3263442516326904 Secs
# Generation 10645 Bred
# Beginning Natural Selection For Generation : 10645 | Population Size : 64
# Generation 10645 High Score : 6 | Duration : 1.2960469722747803 Secs
# Generation 10646 Bred
# Beginning Natural Selection For Generation : 10646 | Population Size : 64
# Generation 10646 High Score : 4 | Duration : 1.3635447025299072 Secs
# Generation 10647 Bred
# Beginning Natural Selection For Generation : 10647 | Population Size : 67
# Generation 10647 High Score : 5 | Duration : 1.3852825164794922 Secs
# Generation 10648 Bred
# Beginning Natural Selection For Generation : 10648 | Population Size : 67
# Generation 10648 High Score : 8 | Duration : 1.4463341236114502 Secs
# Generation 10649 Bred
# Beginning Natural Selection For Generation : 10649 | Population Size : 67
# Generation 10649 High Score : 5 | Duration : 1.4081437587738037 Secs
# Generation 10650 Bred
# Beginning Natural Selection For Generation : 10650 | Population Size : 71
# Generation 10650 High Score : 7 | Duration : 1.2321064472198486 Secs
# Generation 10651 Bred
# Beginning Natural Selection For Generation : 10651 | Population Size : 71
# Generation 10651 High Score : 5 | Duration : 1.3853275775909424 Secs
# Generation 10652 Bred
# Beginning Natural Selection For Generation : 10652 | Population Size : 71
# Generation 10652 High Score : 10 | Duration : 1.73402738571167 Secs
# Generation 10653 Bred
# Beginning Natural Selection For Generation : 10653 | Population Size : 71
# Generation 10653 High Score : 8 | Duration : 1.526191234588623 Secs
# Generation 10654 Bred
# Beginning Natural Selection For Generation : 10654 | Population Size : 71
# Generation 10654 High Score : 10 | Duration : 1.447366714477539 Secs
# Generation 10655 Bred
# Beginning Natural Selection For Generation : 10655 | Population Size : 71
# Generation 10655 High Score : 7 | Duration : 1.5366055965423584 Secs
# Generation 10656 Bred
# Beginning Natural Selection For Generation : 10656 | Population Size : 71
# Generation 10656 High Score : 16 | Duration : 1.4384393692016602 Secs
# Generation 10657 Bred
# Beginning Natural Selection For Generation : 10657 | Population Size : 71
# Generation 10657 High Score : 9 | Duration : 1.5306527614593506 Secs
# Generation 10658 Bred
# Beginning Natural Selection For Generation : 10658 | Population Size : 71
# Generation 10658 High Score : 6 | Duration : 1.8088679313659668 Secs
# Generation 10659 Bred
# Beginning Natural Selection For Generation : 10659 | Population Size : 71
# Generation 10659 High Score : 9 | Duration : 1.6611428260803223 Secs
# Generation 10660 Bred
# Beginning Natural Selection For Generation : 10660 | Population Size : 71
# Generation 10660 High Score : 10 | Duration : 1.4706096649169922 Secs
# Generation 10661 Bred
# Beginning Natural Selection For Generation : 10661 | Population Size : 71
# Generation 10661 High Score : 9 | Duration : 1.6016228199005127 Secs
# Generation 10662 Bred
# Beginning Natural Selection For Generation : 10662 | Population Size : 71
# Generation 10662 High Score : 8 | Duration : 1.6442804336547852 Secs
# Generation 10663 Bred
# Beginning Natural Selection For Generation : 10663 | Population Size : 71
# Generation 10663 High Score : 12 | Duration : 1.5822372436523438 Secs
# Generation 10664 Bred
# Beginning Natural Selection For Generation : 10664 | Population Size : 71
# Generation 10664 High Score : 7 | Duration : 1.7414886951446533 Secs
# Generation 10665 Bred
# Beginning Natural Selection For Generation : 10665 | Population Size : 71
# Generation 10665 High Score : 8 | Duration : 1.8868229389190674 Secs
# Generation 10666 Bred
# Beginning Natural Selection For Generation : 10666 | Population Size : 71
# Generation 10666 High Score : 8 | Duration : 1.6914033889770508 Secs
# Generation 10667 Bred
# Beginning Natural Selection For Generation : 10667 | Population Size : 71
# Generation 10667 High Score : 4 | Duration : 1.555988073348999 Secs
# Generation 10668 Bred
# Beginning Natural Selection For Generation : 10668 | Population Size : 75
# Generation 10668 High Score : 8 | Duration : 2.1933493614196777 Secs
# Generation 10669 Bred
# Beginning Natural Selection For Generation : 10669 | Population Size : 75
# Generation 10669 High Score : 4 | Duration : 1.1442742347717285 Secs
# Generation 10670 Bred
# Beginning Natural Selection For Generation : 10670 | Population Size : 79
# Generation 10670 High Score : 9 | Duration : 1.2573466300964355 Secs
# Generation 10671 Bred
# Beginning Natural Selection For Generation : 10671 | Population Size : 79
# Generation 10671 High Score : 6 | Duration : 1.3853261470794678 Secs
# Generation 10672 Bred
# Beginning Natural Selection For Generation : 10672 | Population Size : 79
# Generation 10672 High Score : 12 | Duration : 1.9423823356628418 Secs
# Generation 10673 Bred
# Beginning Natural Selection For Generation : 10673 | Population Size : 79
# Generation 10673 High Score : 6 | Duration : 2.0837340354919434 Secs
# Generation 10674 Bred
# Beginning Natural Selection For Generation : 10674 | Population Size : 80
# Generation 10674 High Score : 8 | Duration : 1.8530542850494385 Secs
# Generation 10675 Bred
# Beginning Natural Selection For Generation : 10675 | Population Size : 83
# Generation 10675 High Score : 14 | Duration : 1.9145512580871582 Secs
# Generation 10676 Bred
# Beginning Natural Selection For Generation : 10676 | Population Size : 83
# Generation 10676 High Score : 9 | Duration : 2.0802197456359863 Secs
# Generation 10677 Bred
# Beginning Natural Selection For Generation : 10677 | Population Size : 83
# Generation 10677 High Score : 5 | Duration : 2.3114020824432373 Secs
# Generation 10678 Bred
# Beginning Natural Selection For Generation : 10678 | Population Size : 87
# Generation 10678 High Score : 10 | Duration : 1.9869637489318848 Secs
# Generation 10679 Bred
# Beginning Natural Selection For Generation : 10679 | Population Size : 87
# Generation 10679 High Score : 6 | Duration : 1.951746940612793 Secs
# Generation 10680 Bred
# Beginning Natural Selection For Generation : 10680 | Population Size : 87
# Generation 10680 High Score : 8 | Duration : 2.654588460922241 Secs
# Generation 10681 Bred
# Beginning Natural Selection For Generation : 10681 | Population Size : 87
# Generation 10681 High Score : 12 | Duration : 2.579235315322876 Secs
# Generation 10682 Bred
# Beginning Natural Selection For Generation : 10682 | Population Size : 87
# Generation 10682 High Score : 9 | Duration : 2.353968381881714 Secs
# Generation 10683 Bred
# Beginning Natural Selection For Generation : 10683 | Population Size : 87
# Generation 10683 High Score : 6 | Duration : 2.730975866317749 Secs
# Generation 10684 Bred
# Beginning Natural Selection For Generation : 10684 | Population Size : 87
# Generation 10684 High Score : 5 | Duration : 2.521204948425293 Secs
# Generation 10685 Bred
# Beginning Natural Selection For Generation : 10685 | Population Size : 87
# Generation 10685 High Score : 7 | Duration : 2.393681049346924 Secs
# Generation 10686 Bred
# Beginning Natural Selection For Generation : 10686 | Population Size : 87
# Generation 10686 High Score : 8 | Duration : 2.272213935852051 Secs
# Generation 10687 Bred
# Beginning Natural Selection For Generation : 10687 | Population Size : 91
# Generation 10687 High Score : 4 | Duration : 2.44333553314209 Secs
# Generation 10688 Bred
# Beginning Natural Selection For Generation : 10688 | Population Size : 91
# ...
# Generation 14656 High Score : 5 | Duration : 1.8471019268035889 Secs
# Generation 14657 Bred
# Beginning Natural Selection For Generation : 14657 | Population Size : 84
# Generation 14657 High Score : 5 | Duration : 2.0108225345611572 Secs
# Generation 14658 Bred
# Beginning Natural Selection For Generation : 14658 | Population Size : 84
# Generation 14658 High Score : 8 | Duration : 2.178469657897949 Secs
# Generation 14659 Bred
# Beginning Natural Selection For Generation : 14659 | Population Size : 84
# Generation 14659 High Score : 7 | Duration : 1.7960150241851807 Secs
# Generation 14660 Bred
# Beginning Natural Selection For Generation : 14660 | Population Size : 84
# Generation 14660 High Score : 9 | Duration : 2.408613920211792 Secs
# Generation 14661 Bred
# Beginning Natural Selection For Generation : 14661 | Population Size : 84
# Generation 14661 High Score : 8 | Duration : 2.207693338394165 Secs
# Generation 14662 Bred
# Beginning Natural Selection For Generation : 14662 | Population Size : 84
# Generation 14662 High Score : 8 | Duration : 1.9899022579193115 Secs
# Generation 14663 Bred
# Beginning Natural Selection For Generation : 14663 | Population Size : 84
# Generation 14663 High Score : 7 | Duration : 2.612426996231079 Secs
# Generation 14664 Bred
# Beginning Natural Selection For Generation : 14664 | Population Size : 84
# Generation 14664 High Score : 12 | Duration : 2.0023913383483887 Secs
# Generation 14665 Bred
# Beginning Natural Selection For Generation : 14665 | Population Size : 84
# Generation 14665 High Score : 10 | Duration : 2.0469868183135986 Secs
# Generation 14666 Bred
# Beginning Natural Selection For Generation : 14666 | Population Size : 84
# Generation 14666 High Score : 7 | Duration : 1.8977322578430176 Secs
# Generation 14667 Bred
# Beginning Natural Selection For Generation : 14667 | Population Size : 84
# Generation 14667 High Score : 8 | Duration : 2.1332931518554688 Secs
# Generation 14668 Bred
# Beginning Natural Selection For Generation : 14668 | Population Size : 84
# Generation 14668 High Score : 7 | Duration : 2.3663711547851562 Secs
# Generation 14669 Bred
# Beginning Natural Selection For Generation : 14669 | Population Size : 84
# Generation 14669 High Score : 9 | Duration : 2.17694091796875 Secs
# Generation 14670 Bred
# Beginning Natural Selection For Generation : 14670 | Population Size : 84
# Generation 14670 High Score : 9 | Duration : 1.8560717105865479 Secs
# Generation 14671 Bred
# Beginning Natural Selection For Generation : 14671 | Population Size : 87
# Generation 14671 High Score : 7 | Duration : 1.921046257019043 Secs
# Generation 14672 Bred
# Beginning Natural Selection For Generation : 14672 | Population Size : 87
# Generation 14672 High Score : 8 | Duration : 2.1194441318511963 Secs
# Generation 14673 Bred
# Beginning Natural Selection For Generation : 14673 | Population Size : 87
# Generation 14673 High Score : 18 | Duration : 2.150651454925537 Secs
# Generation 14674 Bred
# Beginning Natural Selection For Generation : 14674 | Population Size : 87
# Generation 14674 High Score : 10 | Duration : 2.0702996253967285 Secs
# Generation 14675 Bred
# Beginning Natural Selection For Generation : 14675 | Population Size : 87
# Generation 14675 High Score : 6 | Duration : 2.2082319259643555 Secs
# Generation 14676 Bred
# Beginning Natural Selection For Generation : 14676 | Population Size : 87
# Generation 14676 High Score : 8 | Duration : 2.2895352840423584 Secs
# Generation 14677 Bred
# Beginning Natural Selection For Generation : 14677 | Population Size : 87
# Generation 14677 High Score : 6 | Duration : 2.545468330383301 Secs
# Generation 14678 Bred
# Beginning Natural Selection For Generation : 14678 | Population Size : 87
# Generation 14678 High Score : 12 | Duration : 2.7245256900787354 Secs
# Generation 14679 Bred
# Beginning Natural Selection For Generation : 14679 | Population Size : 87
# Generation 14679 High Score : 17 | Duration : 2.499835252761841 Secs
# Generation 14680 Bred
# Beginning Natural Selection For Generation : 14680 | Population Size : 87
# Generation 14680 High Score : 10 | Duration : 2.513725996017456 Secs
# Generation 14681 Bred
# Beginning Natural Selection For Generation : 14681 | Population Size : 87
# Generation 14681 High Score : 5 | Duration : 2.633258581161499 Secs
# Generation 14682 Bred
# Beginning Natural Selection For Generation : 14682 | Population Size : 91
# Generation 14682 High Score : 14 | Duration : 2.625326633453369 Secs
# Generation 14683 Bred
# Beginning Natural Selection For Generation : 14683 | Population Size : 91
# Generation 14683 High Score : 6 | Duration : 2.4621336460113525 Secs
# Generation 14684 Bred
# Beginning Natural Selection For Generation : 14684 | Population Size : 91
# Generation 14684 High Score : 13 | Duration : 2.2820944786071777 Secs
# Generation 14685 Bred
# Beginning Natural Selection For Generation : 14685 | Population Size : 91
# Generation 14685 High Score : 10 | Duration : 2.835130453109741 Secs
# Generation 14686 Bred
# Beginning Natural Selection For Generation : 14686 | Population Size : 91
# Generation 14686 High Score : 8 | Duration : 2.3907599449157715 Secs
# Generation 14687 Bred
# Beginning Natural Selection For Generation : 14687 | Population Size : 91
# Generation 14687 High Score : 15 | Duration : 2.6674540042877197 Secs
# Generation 14688 Bred
# Beginning Natural Selection For Generation : 14688 | Population Size : 91
# Generation 14688 High Score : 8 | Duration : 2.5419960021972656 Secs
# Generation 14689 Bred
# Beginning Natural Selection For Generation : 14689 | Population Size : 91
# Generation 14689 High Score : 13 | Duration : 2.440356969833374 Secs
# Generation 14690 Bred
# Beginning Natural Selection For Generation : 14690 | Population Size : 91
# Generation 14690 High Score : 11 | Duration : 2.7493340969085693 Secs
# Generation 14691 Bred
# Beginning Natural Selection For Generation : 14691 | Population Size : 91
# Generation 14691 High Score : 7 | Duration : 2.642188549041748 Secs
# Generation 14692 Bred
# Beginning Natural Selection For Generation : 14692 | Population Size : 91
# Generation 14692 High Score : 7 | Duration : 2.6257944107055664 Secs
# Generation 14693 Bred
# Beginning Natural Selection For Generation : 14693 | Population Size : 91
# Generation 14693 High Score : 7 | Duration : 2.400139570236206 Secs
# Generation 14694 Bred
# Beginning Natural Selection For Generation : 14694 | Population Size : 91
# Generation 14694 High Score : 6 | Duration : 2.744375705718994 Secs
# Generation 14695 Bred
# Beginning Natural Selection For Generation : 14695 | Population Size : 91
# Generation 14695 High Score : 6 | Duration : 2.5826685428619385 Secs
# Generation 14696 Bred
# Beginning Natural Selection For Generation : 14696 | Population Size : 92
# Generation 14696 High Score : 11 | Duration : 2.02565336227417 Secs
# Generation 14697 Bred
# Beginning Natural Selection For Generation : 14697 | Population Size : 92
# Generation 14697 High Score : 10 | Duration : 2.593090057373047 Secs
# Generation 14698 Bred
# Beginning Natural Selection For Generation : 14698 | Population Size : 92
# Generation 14698 High Score : 6 | Duration : 2.635777711868286 Secs
# Generation 14699 Bred
# Beginning Natural Selection For Generation : 14699 | Population Size : 92
# Generation 14699 High Score : 7 | Duration : 2.13382625579834 Secs
# Generation 14700 Bred
# Beginning Natural Selection For Generation : 14700 | Population Size : 92
# Generation 14700 High Score : 7 | Duration : 2.2979650497436523 Secs
# Generation 14701 Bred
# Beginning Natural Selection For Generation : 14701 | Population Size : 95
# Generation 14701 High Score : 5 | Duration : 2.5539376735687256 Secs
# Generation 14702 Bred
# Beginning Natural Selection For Generation : 14702 | Population Size : 99
# Generation 14702 High Score : 7 | Duration : 1.8773610591888428 Secs
# Generation 14703 Bred
# Beginning Natural Selection For Generation : 14703 | Population Size : 99
# Generation 14703 High Score : 8 | Duration : 2.759286880493164 Secs
# Generation 14704 Bred
# Beginning Natural Selection For Generation : 14704 | Population Size : 103
# Generation 14704 High Score : 12 | Duration : 3.375814437866211 Secs
# Generation 14705 Bred
# Beginning Natural Selection For Generation : 14705 | Population Size : 103
# Generation 14705 High Score : 13 | Duration : 3.365851640701294 Secs
# Generation 14706 Bred
# Beginning Natural Selection For Generation : 14706 | Population Size : 103
# Generation 14706 High Score : 11 | Duration : 2.9878578186035156 Secs
# Generation 14707 Bred
# Beginning Natural Selection For Generation : 14707 | Population Size : 103
# Generation 14707 High Score : 12 | Duration : 3.3534557819366455 Secs
# Generation 14708 Bred
# Beginning Natural Selection For Generation : 14708 | Population Size : 103
# Generation 14708 High Score : 7 | Duration : 3.0836734771728516 Secs
# Generation 14709 Bred
# Beginning Natural Selection For Generation : 14709 | Population Size : 103
# Generation 14709 High Score : 5 | Duration : 3.4794750213623047 Secs
# Generation 14710 Bred
# Beginning Natural Selection For Generation : 14710 | Population Size : 103
# Generation 14710 High Score : 11 | Duration : 2.5672504901885986 Secs
# Generation 14711 Bred
# Beginning Natural Selection For Generation : 14711 | Population Size : 107
# Generation 14711 High Score : 8 | Duration : 2.7929742336273193 Secs
# Generation 14712 Bred
# Beginning Natural Selection For Generation : 14712 | Population Size : 107
# Generation 14712 High Score : 13 | Duration : 3.9089725017547607 Secs
# Generation 14713 Bred
# Beginning Natural Selection For Generation : 14713 | Population Size : 107
# Generation 14713 High Score : 6 | Duration : 4.360824346542358 Secs
# Generation 14714 Bred
# Beginning Natural Selection For Generation : 14714 | Population Size : 107
# Generation 14714 High Score : 7 | Duration : 3.2602052688598633 Secs
# Generation 14715 Bred
# Beginning Natural Selection For Generation : 14715 | Population Size : 107
# Generation 14715 High Score : 7 | Duration : 3.3212621212005615 Secs
# Generation 14716 Bred
# Beginning Natural Selection For Generation : 14716 | Population Size : 107
# Generation 14716 High Score : 14 | Duration : 3.1243014335632324 Secs
# Generation 14717 Bred
# Beginning Natural Selection For Generation : 14717 | Population Size : 107
# Generation 14717 High Score : 8 | Duration : 3.4234299659729004 Secs
# Generation 14718 Bred
# Beginning Natural Selection For Generation : 14718 | Population Size : 111
# Generation 14718 High Score : 7 | Duration : 3.817706823348999 Secs
# Generation 14719 Bred
# Beginning Natural Selection For Generation : 14719 | Population Size : 115
# Generation 14719 High Score : 4 | Duration : 3.555820941925049 Secs
# Generation 14720 Bred
# Beginning Natural Selection For Generation : 14720 | Population Size : 115
# Generation 14720 High Score : 5 | Duration : 3.225526809692383 Secs
# Generation 14721 Bred
# Beginning Natural Selection For Generation : 14721 | Population Size : 119
# Generation 14721 High Score : 10 | Duration : 2.964132785797119 Secs
# Generation 14722 Bred
# Beginning Natural Selection For Generation : 14722 | Population Size : 119
# Generation 14722 High Score : 8 | Duration : 3.1496329307556152 Secs
# Generation 14723 Bred
# Beginning Natural Selection For Generation : 14723 | Population Size : 119
# Generation 14723 High Score : 8 | Duration : 5.1435534954071045 Secs
# Generation 14724 Bred
# Beginning Natural Selection For Generation : 14724 | Population Size : 119
# Generation 14724 High Score : 10 | Duration : 4.205546855926514 Secs
# Generation 14725 Bred
# Beginning Natural Selection For Generation : 14725 | Population Size : 119
# Generation 14725 High Score : 7 | Duration : 4.4491143226623535 Secs
# Generation 14726 Bred
# Beginning Natural Selection For Generation : 14726 | Population Size : 119
# Generation 14726 High Score : 9 | Duration : 3.9684479236602783 Secs
# Generation 14727 Bred
# Beginning Natural Selection For Generation : 14727 | Population Size : 119
# Generation 14727 High Score : 8 | Duration : 4.714936017990112 Secs
# Generation 14728 Bred
# Beginning Natural Selection For Generation : 14728 | Population Size : 119
# Generation 14728 High Score : 5 | Duration : 4.9064271450042725 Secs
# Generation 14729 Bred
# Beginning Natural Selection For Generation : 14729 | Population Size : 119
# Generation 14729 High Score : 8 | Duration : 4.861324071884155 Secs
# Generation 14730 Bred
# Beginning Natural Selection For Generation : 14730 | Population Size : 123
# Generation 14730 High Score : 9 | Duration : 3.72446870803833 Secs
# Generation 14731 Bred
# Beginning Natural Selection For Generation : 14731 | Population Size : 123
# Generation 14731 High Score : 14 | Duration : 3.7289204597473145 Secs
# Generation 14732 Bred
# Beginning Natural Selection For Generation : 14732 | Population Size : 123
# Generation 14732 High Score : 7 | Duration : 4.919824123382568 Secs
# Generation 14733 Bred
# Beginning Natural Selection For Generation : 14733 | Population Size : 127
# Generation 14733 High Score : 15 | Duration : 4.195673227310181 Secs
# Generation 14734 Bred
# Beginning Natural Selection For Generation : 14734 | Population Size : 131
# Generation 14734 High Score : 10 | Duration : 3.4982857704162598 Secs
# Generation 14735 Bred
# Beginning Natural Selection For Generation : 14735 | Population Size : 131
# Generation 14735 High Score : 9 | Duration : 2.6813747882843018 Secs
# Generation 14736 Bred
# Beginning Natural Selection For Generation : 14736 | Population Size : 131
# Generation 14736 High Score : 21 | Duration : 3.388213634490967 Secs
# Generation 14737 Bred
# Beginning Natural Selection For Generation : 14737 | Population Size : 131
# Generation 14737 High Score : 10 | Duration : 4.9252235889434814 Secs
# Generation 14738 Bred
# Beginning Natural Selection For Generation : 14738 | Population Size : 135
# Generation 14738 High Score : 7 | Duration : 4.731379270553589 Secs
# Generation 14739 Bred
# Beginning Natural Selection For Generation : 14739 | Population Size : 135
# Generation 14739 High Score : 9 | Duration : 4.999674558639526 Secs
# Generation 14740 Bred
# Beginning Natural Selection For Generation : 14740 | Population Size : 139
# Generation 14740 High Score : 8 | Duration : 5.491208076477051 Secs
# Generation 14741 Bred
# Beginning Natural Selection For Generation : 14741 | Population Size : 139
# Generation 14741 High Score : 8 | Duration : 4.926759481430054 Secs
# Generation 14742 Bred
# Beginning Natural Selection For Generation : 14742 | Population Size : 139
# Generation 14742 High Score : 5 | Duration : 5.124212741851807 Secs
# Generation 14743 Bred
# Beginning Natural Selection For Generation : 14743 | Population Size : 143
# Generation 14743 High Score : 7 | Duration : 5.499644041061401 Secs
# Generation 14744 Bred
# Beginning Natural Selection For Generation : 14744 | Population Size : 143
# Generation 14744 High Score : 12 | Duration : 5.366750478744507 Secs
# Generation 14745 Bred
# Beginning Natural Selection For Generation : 14745 | Population Size : 143
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-fca729736244> in <module>()
# ----> 1 subject_popultaion_to_natural_selection(population,generation,name='eigthTrial',num_of_generations=10000,verbose_crawl=False)
#
# <ipython-input-8-c39d37b595a4> in subject_popultaion_to_natural_selection(population, starting_generation, name, num_of_generations, verbose_crawl)
#     109                     logic_engine_1 = logic_engine_wrapper(logic_engine=population[i][0])
#     110                     logic_engine_2 = logic_engine_wrapper(logic_engine=population[i+j][0])
# --> 111                     result = play_game(logic_engines=[logic_engine_1,logic_engine_2],verbose=False,ai_delay=0)
#     112                     if result == 1:
#     113                         new_population[i] = (new_population[i][0],new_population[i][1]+1)
#
# <ipython-input-2-21c78ad8bc15> in play_game(logic_engines, verbose, ai_delay)
#     118             if verbose:
#     119                 print("Thinking...")
# --> 120             time.sleep(ai_delay)
#     121             slot = None
#     122             if current_player == 1:
#
# KeyboardInterrupt:

# %%
population = load_wrapped_net_population('fifthTrial')[0]

# %%
population  = population[:30]
len(population)
# Out:
# 30

# %%
logic_engine_1 = logic_engine_wrapper(logic_engine=population[3][0])
logic_engine_2 = logic_engine_wrapper(logic_engine=population[5][0])
result = play_game(logic_engines=[logic_engine_1,logic_engine_2],verbose=True,ai_delay=0)
# Out:
# |       |
# |       |
# |       |
# |       |
# |       |
# |       |
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |       |
# |       |
# |#      |
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |       |
# |       |
# |#     @|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |       |
# |#      |
# |#     @|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |#      |
# |#     @|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |#      |
# |#    #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |#      |
# |#@   #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |##     |
# |#@   #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |@      |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |       |
# |#      |
# |@      |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |       |
# |#      |
# |@@     |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@#     |
# |##    @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@#     |
# |###   @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@#     |
# |###   @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |###   @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |###   @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |###   @|
# |#@@# #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |###   @|
# |#@@# #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |####  @|
# |#@@# #@|
# ---------
#  1234567

# %%
len(generate_standard_net().hidden_layers[0])
# Out:
# 42
