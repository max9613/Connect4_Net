# %%
# Import statements
import numpy as np
import random as rand
import os
import pandas
import time

# %%
# This cell contains all Connect4 related functions.

# This is a wrapper class that holds the logic engine and returns a decision.
class logic_engine_wrapper:

    # Defaults logic_engine to 0 so that it will just move over one space each turn.
    def __init__(self,logic_engine=0):
        self.logic_engine = logic_engine

    # Returns the logic_engine's move based on the provided board.
    def get_move(self,board):
        if type(self.logic_engine) is int:
            if self.logic_engine >= 6:
                self.logic_engine = 0
                return 6
            else:
                self.logic_engine += 1
                return self.logic_engine - 1
        else:
            output = self.logic_engine.get_output_vector(board.get_board_vector())
            greatest = 0
            for i in range(len(output)):
                if output[i] > output[greatest]:
                    greatest = i
            return greatest
                    
# This class represents a Connect4 board and contains all necessary utilities for it.
# On boards player1 = 1, player2 = -1, and blank = 0.
# The higher the first index the higher on the board i.e. index [5][6] is the top right corner of the board.
class game_board:

    # Creates a 7 x 6 game board.
    def __init__(self):
        self.board = [[0.0 for _ in range(7)] for _ in range(6)]

    # Prints the current game board.
    def print_board(self,player1_symbol='@',player2_symbol='#',clear=False):
        if clear:
            os.system('cls')
        for row in self.board[::-1]:
            print('|',end='')
            for num in row:
                symbol = player1_symbol if num == 1 else (player2_symbol if num == -1 else ' ')
                print(symbol,end='')
            print('|')
        print('---------')
        print(' 1234567 ')

    # Drops a piece into the indicated slot using a range of [0,6]
    def drop_piece(self,slot,player):
        if slot > 6 or slot < 0:
            return False
        else:
            for i in range(6):
                if self.board[i][slot] == 0:
                    self.board[i][slot] = player
                    return True
            return False

    # Returns the board squashed into a numpy array. (This is a utility function for net use)
    def get_board_vector(self):
        board_vector = []
        for row in self.board:
            board_vector += row
        return np.array(board_vector)

    # Returns a player if one of them as won otherwise returns 0.
    def get_winner(self):
        # Checks rows.
        for row in self.board:
            previous = None
            count = 0
            for num in row:
                if num == previous:
                    count += 1
                else:
                    previous = num
                    count = 1
                if count >= 4 and previous != 0:
                    return previous
        # Checks columns.
        for x in range(7):
            previous = None
            count = 0
            for y in range(6):
                num = self.board[y][x]
                if num == previous:
                    count += 1
                else:
                    previous = num
                    count = 1
                if count >= 4 and previous != 0:
                    return previous
        # Checks diagonals.
        for y in range(6):
            for x in range(7):
                num = self.board[y][x]
                if num != 0 and y < 3:
                    if x < 4:
                        if num == self.board[y+1][x+1] and num == self.board[y+2][x+2] and num == self.board[y+3][x+3]:
                            return num
                    elif x > 2:
                        if num == self.board[y+1][x-1] and num == self.board[y+2][x-2] and num == self.board[y+3][x-3]:
                            return num

        return 0


# This function enables the user to play against a logic_engine or lets two logic_engines play against each other.
def play_game(logic_engines=[logic_engine_wrapper()],verbose=True,ai_delay=0.2):
    board = game_board()
    current_player = 1 if rand.choice([True,False]) else -1
    max_num_of_turns = 6 * 7
    for turn in range(max_num_of_turns):
        if verbose:
            board.print_board(clear=True)
        if len(logic_engines) == 2:
            if verbose:
                print("Thinking...")
            time.sleep(ai_delay)
            slot = None
            if current_player == 1:
                proxy_board = game_board()
                for y in range(len(proxy_board.board)):
                    for x in range(len(proxy_board.board[y])):
                        proxy_board.board[y][x] = -1 * board.board[y][x]
                slot = logic_engines[0].get_move(proxy_board)
            else:
                slot = logic_engines[1].get_move(board)
            board.drop_piece(slot,current_player)
        else:
            if current_player == 1:
                slot = int(input('Input a slot: ')) - 1
                board.drop_piece(slot,current_player)
            else:
                if verbose:
                    print("Thinking...")
                time.sleep(ai_delay)
                slot = logic_engines[0].get_move(board)
                board.drop_piece(slot,current_player)
        winner = board.get_winner()
        if winner != 0:
            if verbose:
                board.print_board(clear=True)
            return winner
        else:
            current_player = 1 if current_player == -1 else -1
        if turn == (6 * 7) - 1 and verbose:
            board.print_board(clear=True)
    return 0

# %%
#Non-linear functions are declared in this cell.

#Sigmoid function.
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# Info String Seperators:
net_section_seperator = '|'
net_sub_section_seperator = ':' # i.e. each hidden layer and each bias layer
net_matrix_row_seperator = '>'
net_vector_index_seperator = ','

# %%
# Feedforward network class that's used.
class net:
    
    # wiki_net class constructor.
    def __init__(self,input_size,hidden_layers,non_linears=sigmoid,use_biases=True,name="N/A"):
        self.hidden_layers = []
        self.non_linears = []
        self.biases = []
        self.name = name
        if type(non_linears) != list:
            non_linears = [non_linears] * len(hidden_layers) 
            previous_size = input_size
        elif len(non_linears) == 1:
            non_linears *= len(hidden_layers)
        for i in range(len(hidden_layers)):
            self.hidden_layers.append(2 * np.random.random((previous_size,hidden_layers[i])) - 1)
            self.non_linears.append(non_linears[i])
            self.biases.append(2 * np.random.random(hidden_layers[i]) - 1 if use_biases else np.zeros(hidden_layers[i]))
            previous_size = hidden_layers[i]
    
    # Gets the output vector for a given input vector.
    def get_output_vector(self,input_vector):
        output_vector = input_vector
        for i in range(len(self.hidden_layers)):
            output_vector = self.non_linears[i](np.dot(output_vector,self.hidden_layers[i] + self.biases[i]))
        return output_vector
    
    # Returns a string that contains all of the network's features in the following order, [Name, Score, Hidden_Layers, Biases]
    def generate_info_string(self,score=0):
        info_string = f'{self.name}{net_section_seperator}{score}{net_section_seperator}'
        count_1 = 0
        count_2 = 0
        count_3 = 0
        for layer in self.hidden_layers:
            for vector in layer:
                for index in vector:
                    info_string += f'{index}'
                    info_string += net_vector_index_seperator if count_1 != len(vector) - 1 else ''
                    count_1 += 1
                count_1 = 0
                info_string += net_matrix_row_seperator if count_2 != len(layer) - 1 else ''
                count_2 += 1
            count_2 = 0
            info_string += net_sub_section_seperator if count_3 != len(self.hidden_layers) - 1 else ''
            count_3 += 1
        info_string += net_section_seperator
        count_1 = 0
        count_2 = 0
        for bias in self.biases:
            for index in bias:
                info_string += f'{index}'
                info_string += net_vector_index_seperator if count_1 != len(bias) - 1 else ''
                count_1 += 1
            count_1 = 0
            info_string += net_sub_section_seperator if count_2 != len(self.biases) - 1 else ''
            count_2 += 1
        return info_string
    
    # Loads the net's attribute's from a given string and returns it's score.
    # String Format is listed above the generate_info_string method
    def load_info_from_string(self,info_string,non_linear=sigmoid):
        sections = info_string.split(net_section_seperator)
        self.name = sections[0]
        score = float(sections[1])
        self.hidden_layers = []
        self.biases = []
        self.non_linears = [non_linear]
        hidden_layer_sections = sections[2].split(net_sub_section_seperator)
        for layer in hidden_layer_sections:
            vectors = []
            for text_vector in layer.split(net_matrix_row_seperator):
                vector = []
                for index in text_vector.split(net_vector_index_seperator):
                    vector.append(float(index))
                vectors.append(vector)
            self.hidden_layers.append(np.array(vectors))
        self.non_linears *= len(self.hidden_layers)
        text_biases = sections[3].split(net_sub_section_seperator)
        for text_bias in text_biases:
            bias = []
            for index in text_bias.split(net_vector_index_seperator):
                bias.append(float(index))
            self.biases.append(np.array(bias))
        return score

# %%
# All functions related to saving and loading data are in this cell.

# Saves the given wrapped net population.
def save_wrapped_net_population(population,name,generation):
    try:
        file = open(f'Populations/{name}.snp','w')
        file.write(f'Generation {generation}')
        for wrapped_net in population:
            file.write(f'\n{wrapped_net[0].generate_info_string(wrapped_net[1])}')
        file.close()
    except:
        print(f'Failed to save population : {name}')
        
# Loads a net population from a given file in format (population,generation)
def load_wrapped_net_population(name):
    file = None
    try:
        file = open(f'Populations/{name}.snp','r')
    except:
        print(f'Failed to find file for population : {name}')
        return None
    if file != None:
        contents = file.read().split('\n')
        generation = int(contents[0].split(' ')[1])
        population = []
        for val in contents[1:]:
            net = generate_standard_net()
            score = net.load_info_from_string(val)
            population.append((net,score))
        return (population,generation)

# %%
# Generates a net_net with preset values (this is basically a way to make net generation easier).
def generate_standard_net(name="N/A"): 
    return net(input_size=42,hidden_layers=[7],name=name)
    #return net(input_size=42,hidden_layers=[20,10,7],name=name)
    #return net_net(input_size=5,hidden_layers=[3,2,1],name=name)

# %%
# Genetic evolution related functions are declared in this cell.

# Breeds two nets using indexed addition and the specified weight, mates child with a random net if mutating.
def breed_nets(net_1,net_2,mutation=False,non_linear=sigmoid,name="N/A"):
    hidden_layers = []
    biases = []
    non_linears = []
    for i in range(len(net_1.hidden_layers)):
        #hidden_layers.append((net_1.hidden_layers[i] * net_1_weight) + (net_2.hidden_layers[i] * (1 - net_1_weight)))
        #biases.append((net_1.biases[i] * net_1_weight) + (net_2.biases[i] * (1 - net_1_weight)))
        non_linears.append(non_linear)
        hidden_layers.append([])
        biases.append([])
        for j in range(len(net_1.hidden_layers[i])):
            hidden_layers[i].append((rand.choice([net_1,net_2])).hidden_layers[i][j])
        hidden_layers[i] = np.array(hidden_layers[i])
        for j in range(len(net_1.biases[i])):
            biases[i].append((rand.choice([net_1,net_2])).biases[i][j])
        biases[i] = np.array(biases[i])
    child = generate_standard_net(name=name)
    child.hidden_layers = hidden_layers
    child.biases = biases
    child.non_linears = non_linears
    if mutation:
        return breed_nets(child,generate_standard_net(),name=name)
    else:
        return child

# Breeds a population of ordered wrapped nets.
def breed_wrapped_net_popultation(old_population,generation):
    avg_score = 0
    old_size = len(old_population)
    for wrapped_net in old_population:
        avg_score += wrapped_net[1]
    avg_score /= len(old_population)
    new_population = []
    rand.shuffle(old_population)
    for wrapped_net in old_population:
        if wrapped_net[1] >= avg_score and len(new_population) < len(old_population) / 2:
            new_population.append(wrapped_net)
    old_population = new_population
    new_population = []
    child_num = 0
    rand.shuffle(old_population)
    while len(old_population) > 1:
        wrapped_nets = [old_population.pop(),old_population.pop()]
        score_sum = wrapped_nets[0][1] + wrapped_nets[1][1]
        child_num += 1
        child_1 = breed_nets(wrapped_nets[0][0],wrapped_nets[1][0],mutation=np.random.random(1)[0] > 0.95,name=f'Net : {child_num} (Generation : {generation})')
        child_num += 1
        child_2 = breed_nets(wrapped_nets[0][0],wrapped_nets[1][0],mutation=np.random.random(1)[0] > 0.95,name=f'Net : {child_num} (Generation : {generation})')
        new_population.append((child_1,0))
        new_population.append((child_2,0))
        if avg_score <= 0:
            if np.random.random(1)[0] > 0.5:
                new_population = add_wrapped_net(new_population,wrapped_nets[0])
            else:
                new_population = add_wrapped_net(new_population,wrapped_nets[1])
        else:
            for wrapped_net in wrapped_nets:
                if wrapped_net[1] >= avg_score:
                        new_population = add_wrapped_net(new_population,wrapped_net)
    if len(old_population) <= 3:
            child_num += 1
            new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
            child_num += 1
            new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
            child_num += 1
            new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
    while len(old_population) > 0:
        new_population = add_wrapped_net(new_population,old_population.pop())
    if len(new_population) <= 0:
        for _ in range(8):
            child_num += 1
            new_population.append((generate_standard_net_net(name=f'Net : {child_num} (Generation : {generation})'),0))
    while len(new_population) < old_size:
        child_num += 1
        new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
   # if generation % 4:
           # child_num += 1
           # new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
    if generation % 200 == 0:
        new_population = new_population[:20]
        for _ in range(25):
            child_num += 1
            new_population.append((generate_standard_net(name=f'Net : {child_num} (Generation : {generation})'),0))
    return new_population
    
# Subjects a population to natural selection for the given number of generations.
def subject_popultaion_to_natural_selection(population,starting_generation,name,num_of_generations=100,verbose_crawl=False):
    for i in range(num_of_generations):
        current_generation = starting_generation + i
        print(f'Beginning Natural Selection For Generation : {current_generation} | Population Size : {len(population)}')
        new_population = []
        high_score = 0
        count = 0
        start = time.time()
        for wrapped_net in population:
            new_population.append((wrapped_net[0],0))
        for i in range(len(new_population) - 1):
            for j in range(len(new_population) - i):
                if j != 0:
                    logic_engine_1 = logic_engine_wrapper(logic_engine=population[i][0])
                    logic_engine_2 = logic_engine_wrapper(logic_engine=population[i+j][0])
                    result = play_game(logic_engines=[logic_engine_1,logic_engine_2],verbose=False,ai_delay=0)
                    if result == 1:
                        new_population[i] = (new_population[i][0],new_population[i][1]+1)
                    elif result == -1:
                        new_population[i] = (new_population[i+j][0],new_population[i+j][1]+1)
        proxy_pop = []
        for wrapped_net in new_population:
            add_wrapped_net(proxy_pop,wrapped_net)
            if wrapped_net[1] > high_score:
                high_score = wrapped_net[1]
        new_population = proxy_pop
        end = time.time()
        print(f'Generation {current_generation} High Score : {high_score} | Duration : {end - start} Secs')
        population = breed_wrapped_net_popultation(new_population,current_generation + 1)
        save_wrapped_net_population(population,name,current_generation + 1)
        print(f'Generation {current_generation + 1} Bred')

# Generates a starting population of nets. The nets are in a tuple wrapper of format (net,score)
def generate_base_wrapped_net_population(size=100):
    return [(generate_standard_net(f'Net : {i + 1} (Generation : 0)'),0) for i in range(size)]

# Adds a net wrapper to the given array in order of greatest score.
def add_wrapped_net(array,wrapped_net):
    if len(array) == 0:
        array.append(wrapped_net)
    else:
        placed = False
        for i in range(len(array)):
            if array[i][1] < wrapped_net[1] and not placed:
                array.insert(i,wrapped_net)
                placed = True
        if not placed:
            array.append(wrapped_net)
    return array

# %%
# Creates a new population.
population = generate_base_wrapped_net_population(10)
generation = 0

# %%
# Loads a population from the disk.
hold = load_wrapped_net_population('eigthTrial')
population = hold[0]
generation = hold[1]

# %%
subject_popultaion_to_natural_selection(population,generation,name='eigthTrial',num_of_generations=50000,verbose_crawl=False)
# Out:
# Beginning Natural Selection For Generation : 25143 | Population Size : 107
# Generation 25143 High Score : 6 | Duration : 3.4323604106903076 Secs
# Generation 25144 Bred
# Beginning Natural Selection For Generation : 25144 | Population Size : 107
# Generation 25144 High Score : 18 | Duration : 2.794506788253784 Secs
# Generation 25145 Bred
# Beginning Natural Selection For Generation : 25145 | Population Size : 111
# Generation 25145 High Score : 14 | Duration : 4.033498287200928 Secs
# Generation 25146 Bred
# Beginning Natural Selection For Generation : 25146 | Population Size : 111
# Generation 25146 High Score : 10 | Duration : 3.7953875064849854 Secs
# Generation 25147 Bred
# Beginning Natural Selection For Generation : 25147 | Population Size : 111
# Generation 25147 High Score : 8 | Duration : 3.3484904766082764 Secs
# Generation 25148 Bred
# Beginning Natural Selection For Generation : 25148 | Population Size : 111
# Generation 25148 High Score : 9 | Duration : 3.7815322875976562 Secs
# Generation 25149 Bred
# Beginning Natural Selection For Generation : 25149 | Population Size : 111
# Generation 25149 High Score : 8 | Duration : 3.6371278762817383 Secs
# Generation 25150 Bred
# Beginning Natural Selection For Generation : 25150 | Population Size : 111
# Generation 25150 High Score : 7 | Duration : 2.926435947418213 Secs
# Generation 25151 Bred
# Beginning Natural Selection For Generation : 25151 | Population Size : 111
# Generation 25151 High Score : 11 | Duration : 3.3976480960845947 Secs
# Generation 25152 Bred
# Beginning Natural Selection For Generation : 25152 | Population Size : 111
# Generation 25152 High Score : 6 | Duration : 4.026072263717651 Secs
# Generation 25153 Bred
# Beginning Natural Selection For Generation : 25153 | Population Size : 111
# Generation 25153 High Score : 9 | Duration : 3.105947256088257 Secs
# Generation 25154 Bred
# Beginning Natural Selection For Generation : 25154 | Population Size : 115
# Generation 25154 High Score : 12 | Duration : 3.2205207347869873 Secs
# Generation 25155 Bred
# Beginning Natural Selection For Generation : 25155 | Population Size : 115
# Generation 25155 High Score : 7 | Duration : 3.537430763244629 Secs
# Generation 25156 Bred
# Beginning Natural Selection For Generation : 25156 | Population Size : 115
# Generation 25156 High Score : 11 | Duration : 3.986388683319092 Secs
# Generation 25157 Bred
# Beginning Natural Selection For Generation : 25157 | Population Size : 115
# Generation 25157 High Score : 9 | Duration : 4.149572372436523 Secs
# Generation 25158 Bred
# Beginning Natural Selection For Generation : 25158 | Population Size : 115
# Generation 25158 High Score : 9 | Duration : 4.102946996688843 Secs
# Generation 25159 Bred
# Beginning Natural Selection For Generation : 25159 | Population Size : 115
# Generation 25159 High Score : 5 | Duration : 4.0919928550720215 Secs
# Generation 25160 Bred
# Beginning Natural Selection For Generation : 25160 | Population Size : 119
# Generation 25160 High Score : 21 | Duration : 2.905606269836426 Secs
# Generation 25161 Bred
# Beginning Natural Selection For Generation : 25161 | Population Size : 119
# Generation 25161 High Score : 9 | Duration : 3.5235788822174072 Secs
# Generation 25162 Bred
# Beginning Natural Selection For Generation : 25162 | Population Size : 123
# Generation 25162 High Score : 6 | Duration : 3.610380172729492 Secs
# Generation 25163 Bred
# Beginning Natural Selection For Generation : 25163 | Population Size : 127
# Generation 25163 High Score : 5 | Duration : 6.929117441177368 Secs
# Generation 25164 Bred
# Beginning Natural Selection For Generation : 25164 | Population Size : 127
# Generation 25164 High Score : 4 | Duration : 7.8204240798950195 Secs
# Generation 25165 Bred
# Beginning Natural Selection For Generation : 25165 | Population Size : 127
# Generation 25165 High Score : 7 | Duration : 8.830803394317627 Secs
# Generation 25166 Bred
# Beginning Natural Selection For Generation : 25166 | Population Size : 127
# Generation 25166 High Score : 7 | Duration : 7.407749891281128 Secs
# Generation 25167 Bred
# Beginning Natural Selection For Generation : 25167 | Population Size : 127
# Generation 25167 High Score : 6 | Duration : 5.731815576553345 Secs
# Generation 25168 Bred
# Beginning Natural Selection For Generation : 25168 | Population Size : 127
# Generation 25168 High Score : 9 | Duration : 4.632174730300903 Secs
# Generation 25169 Bred
# Beginning Natural Selection For Generation : 25169 | Population Size : 127
# Generation 25169 High Score : 9 | Duration : 5.99812126159668 Secs
# Generation 25170 Bred
# Beginning Natural Selection For Generation : 25170 | Population Size : 127
# Generation 25170 High Score : 14 | Duration : 5.29929780960083 Secs
# Generation 25171 Bred
# Beginning Natural Selection For Generation : 25171 | Population Size : 128
# Generation 25171 High Score : 12 | Duration : 4.256171703338623 Secs
# Generation 25172 Bred
# Beginning Natural Selection For Generation : 25172 | Population Size : 128
# Generation 25172 High Score : 9 | Duration : 4.247242450714111 Secs
# Generation 25173 Bred
# Beginning Natural Selection For Generation : 25173 | Population Size : 128
# Generation 25173 High Score : 9 | Duration : 4.721949815750122 Secs
# Generation 25174 Bred
# Beginning Natural Selection For Generation : 25174 | Population Size : 128
# Generation 25174 High Score : 7 | Duration : 5.093456506729126 Secs
# Generation 25175 Bred
# Beginning Natural Selection For Generation : 25175 | Population Size : 131
# Generation 25175 High Score : 6 | Duration : 3.9367470741271973 Secs
# Generation 25176 Bred
# Beginning Natural Selection For Generation : 25176 | Population Size : 131
# Generation 25176 High Score : 11 | Duration : 4.382690906524658 Secs
# Generation 25177 Bred
# Beginning Natural Selection For Generation : 25177 | Population Size : 131
# Generation 25177 High Score : 10 | Duration : 5.623682737350464 Secs
# Generation 25178 Bred
# Beginning Natural Selection For Generation : 25178 | Population Size : 131
# Generation 25178 High Score : 9 | Duration : 4.958548069000244 Secs
# Generation 25179 Bred
# Beginning Natural Selection For Generation : 25179 | Population Size : 131
# Generation 25179 High Score : 7 | Duration : 5.420322895050049 Secs
# Generation 25180 Bred
# Beginning Natural Selection For Generation : 25180 | Population Size : 131
# Generation 25180 High Score : 10 | Duration : 5.5155556201934814 Secs
# Generation 25181 Bred
# Beginning Natural Selection For Generation : 25181 | Population Size : 131
# Generation 25181 High Score : 10 | Duration : 5.053778886795044 Secs
# Generation 25182 Bred
# Beginning Natural Selection For Generation : 25182 | Population Size : 131
# Generation 25182 High Score : 9 | Duration : 4.819627285003662 Secs
# Generation 25183 Bred
# Beginning Natural Selection For Generation : 25183 | Population Size : 131
# Generation 25183 High Score : 10 | Duration : 5.634092807769775 Secs
# Generation 25184 Bred
# Beginning Natural Selection For Generation : 25184 | Population Size : 131
# Generation 25184 High Score : 8 | Duration : 4.213554859161377 Secs
# Generation 25185 Bred
# Beginning Natural Selection For Generation : 25185 | Population Size : 131
# Generation 25185 High Score : 15 | Duration : 5.057251453399658 Secs
# Generation 25186 Bred
# Beginning Natural Selection For Generation : 25186 | Population Size : 131
# Generation 25186 High Score : 7 | Duration : 4.978346347808838 Secs
# Generation 25187 Bred
# Beginning Natural Selection For Generation : 25187 | Population Size : 131
# Generation 25187 High Score : 9 | Duration : 6.252556562423706 Secs
# Generation 25188 Bred
# Beginning Natural Selection For Generation : 25188 | Population Size : 131
# Generation 25188 High Score : 9 | Duration : 5.090938329696655 Secs
# Generation 25189 Bred
# Beginning Natural Selection For Generation : 25189 | Population Size : 131
# Generation 25189 High Score : 12 | Duration : 5.100403785705566 Secs
# Generation 25190 Bred
# Beginning Natural Selection For Generation : 25190 | Population Size : 131
# Generation 25190 High Score : 8 | Duration : 5.927726984024048 Secs
# Generation 25191 Bred
# Beginning Natural Selection For Generation : 25191 | Population Size : 131
# Generation 25191 High Score : 9 | Duration : 5.336954593658447 Secs
# Generation 25192 Bred
# Beginning Natural Selection For Generation : 25192 | Population Size : 131
# Generation 25192 High Score : 8 | Duration : 5.2303550243377686 Secs
# Generation 25193 Bred
# Beginning Natural Selection For Generation : 25193 | Population Size : 131
# Generation 25193 High Score : 11 | Duration : 5.0795698165893555 Secs
# Generation 25194 Bred
# Beginning Natural Selection For Generation : 25194 | Population Size : 131
# Generation 25194 High Score : 8 | Duration : 5.159421443939209 Secs
# Generation 25195 Bred
# Beginning Natural Selection For Generation : 25195 | Population Size : 135
# Generation 25195 High Score : 11 | Duration : 4.446139097213745 Secs
# Generation 25196 Bred
# Beginning Natural Selection For Generation : 25196 | Population Size : 139
# Generation 25196 High Score : 5 | Duration : 4.082076072692871 Secs
# Generation 25197 Bred
# Beginning Natural Selection For Generation : 25197 | Population Size : 139
# Generation 25197 High Score : 9 | Duration : 6.701974153518677 Secs
# Generation 25198 Bred
# Beginning Natural Selection For Generation : 25198 | Population Size : 139
# Generation 25198 High Score : 9 | Duration : 6.660318374633789 Secs
# Generation 25199 Bred
# Beginning Natural Selection For Generation : 25199 | Population Size : 139
# Generation 25199 High Score : 11 | Duration : 5.225890159606934 Secs
# Generation 25200 Bred
# Beginning Natural Selection For Generation : 25200 | Population Size : 45
# Generation 25200 High Score : 6 | Duration : 0.6572432518005371 Secs
# Generation 25201 Bred
# Beginning Natural Selection For Generation : 25201 | Population Size : 45
# Generation 25201 High Score : 5 | Duration : 0.6641426086425781 Secs
# Generation 25202 Bred
# Beginning Natural Selection For Generation : 25202 | Population Size : 45
# Generation 25202 High Score : 7 | Duration : 0.7648732662200928 Secs
# Generation 25203 Bred
# Beginning Natural Selection For Generation : 25203 | Population Size : 45
# Generation 25203 High Score : 5 | Duration : 0.6736180782318115 Secs
# Generation 25204 Bred
# Beginning Natural Selection For Generation : 25204 | Population Size : 48
# Generation 25204 High Score : 9 | Duration : 0.5555202960968018 Secs
# Generation 25205 Bred
# Beginning Natural Selection For Generation : 25205 | Population Size : 48
# Generation 25205 High Score : 8 | Duration : 0.6462869644165039 Secs
# Generation 25206 Bred
# Beginning Natural Selection For Generation : 25206 | Population Size : 48
# Generation 25206 High Score : 6 | Duration : 0.7961206436157227 Secs
# Generation 25207 Bred
# Beginning Natural Selection For Generation : 25207 | Population Size : 48
# Generation 25207 High Score : 6 | Duration : 0.8015804290771484 Secs
# Generation 25208 Bred
# Beginning Natural Selection For Generation : 25208 | Population Size : 48
# Generation 25208 High Score : 6 | Duration : 0.7945542335510254 Secs
# Generation 25209 Bred
# Beginning Natural Selection For Generation : 25209 | Population Size : 51
# Generation 25209 High Score : 7 | Duration : 0.7152328491210938 Secs
# Generation 25210 Bred
# Beginning Natural Selection For Generation : 25210 | Population Size : 51
# Generation 25210 High Score : 3 | Duration : 0.9082140922546387 Secs
# Generation 25211 Bred
# Beginning Natural Selection For Generation : 25211 | Population Size : 51
# Generation 25211 High Score : 5 | Duration : 0.8521654605865479 Secs
# Generation 25212 Bred
# Beginning Natural Selection For Generation : 25212 | Population Size : 51
# Generation 25212 High Score : 9 | Duration : 0.7653717994689941 Secs
# Generation 25213 Bred
# Beginning Natural Selection For Generation : 25213 | Population Size : 51
# Generation 25213 High Score : 8 | Duration : 0.827326774597168 Secs
# Generation 25214 Bred
# Beginning Natural Selection For Generation : 25214 | Population Size : 51
# Generation 25214 High Score : 7 | Duration : 0.8144316673278809 Secs
# Generation 25215 Bred
# Beginning Natural Selection For Generation : 25215 | Population Size : 55
# Generation 25215 High Score : 9 | Duration : 0.7063045501708984 Secs
# Generation 25216 Bred
# Beginning Natural Selection For Generation : 25216 | Population Size : 55
# Generation 25216 High Score : 13 | Duration : 0.7792551517486572 Secs
# Generation 25217 Bred
# Beginning Natural Selection For Generation : 25217 | Population Size : 55
# Generation 25217 High Score : 5 | Duration : 0.8194172382354736 Secs
# Generation 25218 Bred
# Beginning Natural Selection For Generation : 25218 | Population Size : 55
# Generation 25218 High Score : 8 | Duration : 0.8114547729492188 Secs
# Generation 25219 Bred
# Beginning Natural Selection For Generation : 25219 | Population Size : 55
# Generation 25219 High Score : 4 | Duration : 1.0728464126586914 Secs
# Generation 25220 Bred
# Beginning Natural Selection For Generation : 25220 | Population Size : 55
# Generation 25220 High Score : 5 | Duration : 1.0282464027404785 Secs
# Generation 25221 Bred
# Beginning Natural Selection For Generation : 25221 | Population Size : 59
# Generation 25221 High Score : 6 | Duration : 0.9969580173492432 Secs
# Generation 25222 Bred
# Beginning Natural Selection For Generation : 25222 | Population Size : 59
# Generation 25222 High Score : 10 | Duration : 1.3109264373779297 Secs
# Generation 25223 Bred
# Beginning Natural Selection For Generation : 25223 | Population Size : 59
# Generation 25223 High Score : 8 | Duration : 0.9518206119537354 Secs
# Generation 25224 Bred
# Beginning Natural Selection For Generation : 25224 | Population Size : 59
# Generation 25224 High Score : 7 | Duration : 1.0257258415222168 Secs
# Generation 25225 Bred
# Beginning Natural Selection For Generation : 25225 | Population Size : 59
# Generation 25225 High Score : 7 | Duration : 1.028702735900879 Secs
# Generation 25226 Bred
# Beginning Natural Selection For Generation : 25226 | Population Size : 59
# Generation 25226 High Score : 8 | Duration : 1.1472465991973877 Secs
# Generation 25227 Bred
# Beginning Natural Selection For Generation : 25227 | Population Size : 59
# Generation 25227 High Score : 9 | Duration : 1.2330994606018066 Secs
# Generation 25228 Bred
# Beginning Natural Selection For Generation : 25228 | Population Size : 59
# Generation 25228 High Score : 7 | Duration : 1.213212013244629 Secs
# Generation 25229 Bred
# Beginning Natural Selection For Generation : 25229 | Population Size : 63
# Generation 25229 High Score : 6 | Duration : 1.2598826885223389 Secs
# Generation 25230 Bred
# Beginning Natural Selection For Generation : 25230 | Population Size : 63
# Generation 25230 High Score : 4 | Duration : 1.2499191761016846 Secs
# Generation 25231 Bred
# Beginning Natural Selection For Generation : 25231 | Population Size : 63
# Generation 25231 High Score : 6 | Duration : 1.084749698638916 Secs
# Generation 25232 Bred
# Beginning Natural Selection For Generation : 25232 | Population Size : 63
# Generation 25232 High Score : 8 | Duration : 1.2608706951141357 Secs
# Generation 25233 Bred
# Beginning Natural Selection For Generation : 25233 | Population Size : 63
# Generation 25233 High Score : 5 | Duration : 1.3020415306091309 Secs
# Generation 25234 Bred
# Beginning Natural Selection For Generation : 25234 | Population Size : 63
# Generation 25234 High Score : 6 | Duration : 1.2251183986663818 Secs
# Generation 25235 Bred
# Beginning Natural Selection For Generation : 25235 | Population Size : 63
# Generation 25235 High Score : 7 | Duration : 1.1487784385681152 Secs
# Generation 25236 Bred
# Beginning Natural Selection For Generation : 25236 | Population Size : 63
# Generation 25236 High Score : 6 | Duration : 1.323822021484375 Secs
# Generation 25237 Bred
# Beginning Natural Selection For Generation : 25237 | Population Size : 63
# Generation 25237 High Score : 5 | Duration : 1.187459945678711 Secs
# Generation 25238 Bred
# Beginning Natural Selection For Generation : 25238 | Population Size : 63
# Generation 25238 High Score : 6 | Duration : 1.0892550945281982 Secs
# Generation 25239 Bred
# Beginning Natural Selection For Generation : 25239 | Population Size : 63
# Generation 25239 High Score : 12 | Duration : 1.2747576236724854 Secs
# Generation 25240 Bred
# Beginning Natural Selection For Generation : 25240 | Population Size : 63
# Generation 25240 High Score : 7 | Duration : 1.2563660144805908 Secs
# Generation 25241 Bred
# Beginning Natural Selection For Generation : 25241 | Population Size : 63
# Generation 25241 High Score : 4 | Duration : 1.402686357498169 Secs
# Generation 25242 Bred
# Beginning Natural Selection For Generation : 25242 | Population Size : 63
# Generation 25242 High Score : 6 | Duration : 1.3139054775238037 Secs
# Generation 25243 Bred
# Beginning Natural Selection For Generation : 25243 | Population Size : 67
# Generation 25243 High Score : 9 | Duration : 1.0480895042419434 Secs
# Generation 25244 Bred
# Beginning Natural Selection For Generation : 25244 | Population Size : 67
# Generation 25244 High Score : 6 | Duration : 1.4478209018707275 Secs
# Generation 25245 Bred
# Beginning Natural Selection For Generation : 25245 | Population Size : 67
# Generation 25245 High Score : 7 | Duration : 1.428523302078247 Secs
# Generation 25246 Bred
# Beginning Natural Selection For Generation : 25246 | Population Size : 67
# Generation 25246 High Score : 6 | Duration : 1.5287086963653564 Secs
# Generation 25247 Bred
# Beginning Natural Selection For Generation : 25247 | Population Size : 67
# Generation 25247 High Score : 9 | Duration : 1.3442072868347168 Secs
# Generation 25248 Bred
# Beginning Natural Selection For Generation : 25248 | Population Size : 67
# Generation 25248 High Score : 10 | Duration : 1.5356552600860596 Secs
# Generation 25249 Bred
# Beginning Natural Selection For Generation : 25249 | Population Size : 67
# Generation 25249 High Score : 6 | Duration : 1.4706377983093262 Secs
# Generation 25250 Bred
# Beginning Natural Selection For Generation : 25250 | Population Size : 71
# Generation 25250 High Score : 9 | Duration : 1.5916635990142822 Secs
# Generation 25251 Bred
# Beginning Natural Selection For Generation : 25251 | Population Size : 71
# Generation 25251 High Score : 8 | Duration : 1.6596572399139404 Secs
# Generation 25252 Bred
# Beginning Natural Selection For Generation : 25252 | Population Size : 72
# Generation 25252 High Score : 7 | Duration : 1.239048719406128 Secs
# Generation 25253 Bred
# Beginning Natural Selection For Generation : 25253 | Population Size : 72
# Generation 25253 High Score : 5 | Duration : 1.5465667247772217 Secs
# Generation 25254 Bred
# Beginning Natural Selection For Generation : 25254 | Population Size : 72
# Generation 25254 High Score : 5 | Duration : 1.8133742809295654 Secs
# Generation 25255 Bred
# Beginning Natural Selection For Generation : 25255 | Population Size : 72
# Generation 25255 High Score : 7 | Duration : 1.4473235607147217 Secs
# Generation 25256 Bred
# Beginning Natural Selection For Generation : 25256 | Population Size : 72
# Generation 25256 High Score : 13 | Duration : 1.8084535598754883 Secs
# Generation 25257 Bred
# Beginning Natural Selection For Generation : 25257 | Population Size : 72
# Generation 25257 High Score : 9 | Duration : 1.4026870727539062 Secs
# Generation 25258 Bred
# Beginning Natural Selection For Generation : 25258 | Population Size : 72
# Generation 25258 High Score : 14 | Duration : 1.6744921207427979 Secs
# Generation 25259 Bred
# Beginning Natural Selection For Generation : 25259 | Population Size : 72
# Generation 25259 High Score : 6 | Duration : 1.5931909084320068 Secs
# Generation 25260 Bred
# Beginning Natural Selection For Generation : 25260 | Population Size : 72
# Generation 25260 High Score : 9 | Duration : 1.5936470031738281 Secs
# Generation 25261 Bred
# Beginning Natural Selection For Generation : 25261 | Population Size : 72
# Generation 25261 High Score : 8 | Duration : 1.5723581314086914 Secs
# Generation 25262 Bred
# Beginning Natural Selection For Generation : 25262 | Population Size : 72
# Generation 25262 High Score : 5 | Duration : 2.061417579650879 Secs
# Generation 25263 Bred
# Beginning Natural Selection For Generation : 25263 | Population Size : 72
# Generation 25263 High Score : 8 | Duration : 1.2812001705169678 Secs
# Generation 25264 Bred
# Beginning Natural Selection For Generation : 25264 | Population Size : 72
# Generation 25264 High Score : 9 | Duration : 1.3868532180786133 Secs
# Generation 25265 Bred
# Beginning Natural Selection For Generation : 25265 | Population Size : 72
# Generation 25265 High Score : 5 | Duration : 1.5029191970825195 Secs
# Generation 25266 Bred
# Beginning Natural Selection For Generation : 25266 | Population Size : 72
# Generation 25266 High Score : 7 | Duration : 1.4037189483642578 Secs
# Generation 25267 Bred
# Beginning Natural Selection For Generation : 25267 | Population Size : 75
# Generation 25267 High Score : 7 | Duration : 1.462702751159668 Secs
# Generation 25268 Bred
# Beginning Natural Selection For Generation : 25268 | Population Size : 79
# Generation 25268 High Score : 5 | Duration : 1.7330660820007324 Secs
# Generation 25269 Bred
# Beginning Natural Selection For Generation : 25269 | Population Size : 79
# Generation 25269 High Score : 9 | Duration : 1.6586711406707764 Secs
# Generation 25270 Bred
# Beginning Natural Selection For Generation : 25270 | Population Size : 79
# Generation 25270 High Score : 8 | Duration : 1.814901351928711 Secs
# Generation 25271 Bred
# Beginning Natural Selection For Generation : 25271 | Population Size : 79
# Generation 25271 High Score : 5 | Duration : 1.7126848697662354 Secs
# Generation 25272 Bred
# Beginning Natural Selection For Generation : 25272 | Population Size : 79
# Generation 25272 High Score : 12 | Duration : 1.918069839477539 Secs
# Generation 25273 Bred
# Beginning Natural Selection For Generation : 25273 | Population Size : 79
# Generation 25273 High Score : 7 | Duration : 1.885829210281372 Secs
# Generation 25274 Bred
# Beginning Natural Selection For Generation : 25274 | Population Size : 83
# Generation 25274 High Score : 5 | Duration : 2.2751901149749756 Secs
# Generation 25275 Bred
# Beginning Natural Selection For Generation : 25275 | Population Size : 83
# Generation 25275 High Score : 5 | Duration : 2.294492721557617 Secs
# Generation 25276 Bred
# Beginning Natural Selection For Generation : 25276 | Population Size : 83
# Generation 25276 High Score : 7 | Duration : 2.3669064044952393 Secs
# Generation 25277 Bred
# Beginning Natural Selection For Generation : 25277 | Population Size : 83
# Generation 25277 High Score : 6 | Duration : 2.003876209259033 Secs
# Generation 25278 Bred
# Beginning Natural Selection For Generation : 25278 | Population Size : 83
# Generation 25278 High Score : 9 | Duration : 2.2567954063415527 Secs
# Generation 25279 Bred
# Beginning Natural Selection For Generation : 25279 | Population Size : 87
# Generation 25279 High Score : 10 | Duration : 1.8213517665863037 Secs
# Generation 25280 Bred
# Beginning Natural Selection For Generation : 25280 | Population Size : 87
# Generation 25280 High Score : 9 | Duration : 2.160076856613159 Secs
# Generation 25281 Bred
# Beginning Natural Selection For Generation : 25281 | Population Size : 87
# Generation 25281 High Score : 4 | Duration : 2.3029661178588867 Secs
# Generation 25282 Bred
# Beginning Natural Selection For Generation : 25282 | Population Size : 87
# Generation 25282 High Score : 5 | Duration : 2.358973741531372 Secs
# Generation 25283 Bred
# Beginning Natural Selection For Generation : 25283 | Population Size : 87
# Generation 25283 High Score : 7 | Duration : 2.2285661697387695 Secs
# Generation 25284 Bred
# Beginning Natural Selection For Generation : 25284 | Population Size : 87
# Generation 25284 High Score : 7 | Duration : 1.7434780597686768 Secs
# Generation 25285 Bred
# Beginning Natural Selection For Generation : 25285 | Population Size : 87
# Generation 25285 High Score : 10 | Duration : 2.069308280944824 Secs
# Generation 25286 Bred
# Beginning Natural Selection For Generation : 25286 | Population Size : 87
# Generation 25286 High Score : 8 | Duration : 2.296973466873169 Secs
# Generation 25287 Bred
# Beginning Natural Selection For Generation : 25287 | Population Size : 87
# Generation 25287 High Score : 7 | Duration : 2.4502360820770264 Secs
# Generation 25288 Bred
# Beginning Natural Selection For Generation : 25288 | Population Size : 91
# Generation 25288 High Score : 10 | Duration : 2.82376766204834 Secs
# Generation 25289 Bred
# Beginning Natural Selection For Generation : 25289 | Population Size : 91
# Generation 25289 High Score : 6 | Duration : 1.7821300029754639 Secs
# Generation 25290 Bred
# Beginning Natural Selection For Generation : 25290 | Population Size : 91
# Generation 25290 High Score : 8 | Duration : 2.548978328704834 Secs
# Generation 25291 Bred
# Beginning Natural Selection For Generation : 25291 | Population Size : 92
# Generation 25291 High Score : 6 | Duration : 2.4016306400299072 Secs
# Generation 25292 Bred
# Beginning Natural Selection For Generation : 25292 | Population Size : 92
# Generation 25292 High Score : 6 | Duration : 2.542534589767456 Secs
# Generation 25293 Bred
# Beginning Natural Selection For Generation : 25293 | Population Size : 95
# Generation 25293 High Score : 10 | Duration : 2.6719894409179688 Secs
# Generation 25294 Bred
# Beginning Natural Selection For Generation : 25294 | Population Size : 95
# Generation 25294 High Score : 8 | Duration : 2.8867602348327637 Secs
# Generation 25295 Bred
# Beginning Natural Selection For Generation : 25295 | Population Size : 95
# Generation 25295 High Score : 9 | Duration : 2.609452486038208 Secs
# Generation 25296 Bred
# Beginning Natural Selection For Generation : 25296 | Population Size : 95
# Generation 25296 High Score : 10 | Duration : 2.7265539169311523 Secs
# Generation 25297 Bred
# Beginning Natural Selection For Generation : 25297 | Population Size : 95
# Generation 25297 High Score : 7 | Duration : 2.0951006412506104 Secs
# Generation 25298 Bred
# Beginning Natural Selection For Generation : 25298 | Population Size : 95
# Generation 25298 High Score : 9 | Duration : 3.2994301319122314 Secs
# Generation 25299 Bred
# Beginning Natural Selection For Generation : 25299 | Population Size : 95
# Generation 25299 High Score : 7 | Duration : 2.6292927265167236 Secs
# Generation 25300 Bred
# Beginning Natural Selection For Generation : 25300 | Population Size : 95
# Generation 25300 High Score : 4 | Duration : 2.380300760269165 Secs
# Generation 25301 Bred
# Beginning Natural Selection For Generation : 25301 | Population Size : 99
# Generation 25301 High Score : 10 | Duration : 2.349592685699463 Secs
# Generation 25302 Bred
# Beginning Natural Selection For Generation : 25302 | Population Size : 99
# Generation 25302 High Score : 7 | Duration : 2.7180798053741455 Secs
# Generation 25303 Bred
# Beginning Natural Selection For Generation : 25303 | Population Size : 99
# Generation 25303 High Score : 9 | Duration : 2.710184097290039 Secs
# Generation 25304 Bred
# Beginning Natural Selection For Generation : 25304 | Population Size : 99
# Generation 25304 High Score : 6 | Duration : 3.2924838066101074 Secs
# Generation 25305 Bred
# Beginning Natural Selection For Generation : 25305 | Population Size : 99
# Generation 25305 High Score : 8 | Duration : 3.093096971511841 Secs
# Generation 25306 Bred
# Beginning Natural Selection For Generation : 25306 | Population Size : 100
# Generation 25306 High Score : 6 | Duration : 3.2810754776000977 Secs
# Generation 25307 Bred
# Beginning Natural Selection For Generation : 25307 | Population Size : 100
# Generation 25307 High Score : 9 | Duration : 3.0167155265808105 Secs
# Generation 25308 Bred
# Beginning Natural Selection For Generation : 25308 | Population Size : 103
# Generation 25308 High Score : 7 | Duration : 2.6947991847991943 Secs
# Generation 25309 Bred
# Beginning Natural Selection For Generation : 25309 | Population Size : 103
# Generation 25309 High Score : 12 | Duration : 3.031548023223877 Secs
# Generation 25310 Bred
# Beginning Natural Selection For Generation : 25310 | Population Size : 103
# Generation 25310 High Score : 10 | Duration : 3.402556896209717 Secs
# Generation 25311 Bred
# Beginning Natural Selection For Generation : 25311 | Population Size : 103
# Generation 25311 High Score : 10 | Duration : 2.6184206008911133 Secs
# Generation 25312 Bred
# Beginning Natural Selection For Generation : 25312 | Population Size : 103
# Generation 25312 High Score : 9 | Duration : 3.452690601348877 Secs
# Generation 25313 Bred
# Beginning Natural Selection For Generation : 25313 | Population Size : 103
# Generation 25313 High Score : 10 | Duration : 3.1838603019714355 Secs
# Generation 25314 Bred
# Beginning Natural Selection For Generation : 25314 | Population Size : 103
# Generation 25314 High Score : 5 | Duration : 2.739406108856201 Secs
# Generation 25315 Bred
# Beginning Natural Selection For Generation : 25315 | Population Size : 103
# Generation 25315 High Score : 9 | Duration : 3.160508155822754 Secs
# Generation 25316 Bred
# Beginning Natural Selection For Generation : 25316 | Population Size : 103
# Generation 25316 High Score : 9 | Duration : 3.0608112812042236 Secs
# Generation 25317 Bred
# Beginning Natural Selection For Generation : 25317 | Population Size : 103
# Generation 25317 High Score : 7 | Duration : 3.3737902641296387 Secs
# Generation 25318 Bred
# Beginning Natural Selection For Generation : 25318 | Population Size : 103
# Generation 25318 High Score : 8 | Duration : 2.926931858062744 Secs
# Generation 25319 Bred
# Beginning Natural Selection For Generation : 25319 | Population Size : 103
# Generation 25319 High Score : 7 | Duration : 2.8639001846313477 Secs
# Generation 25320 Bred
# Beginning Natural Selection For Generation : 25320 | Population Size : 103
# Generation 25320 High Score : 7 | Duration : 3.2478415966033936 Secs
# Generation 25321 Bred
# Beginning Natural Selection For Generation : 25321 | Population Size : 103
# Generation 25321 High Score : 12 | Duration : 2.8133387565612793 Secs
# Generation 25322 Bred
# Beginning Natural Selection For Generation : 25322 | Population Size : 103
# Generation 25322 High Score : 7 | Duration : 3.072751522064209 Secs
# Generation 25323 Bred
# Beginning Natural Selection For Generation : 25323 | Population Size : 103
# Generation 25323 High Score : 8 | Duration : 3.397627592086792 Secs
# Generation 25324 Bred
# Beginning Natural Selection For Generation : 25324 | Population Size : 103
# Generation 25324 High Score : 10 | Duration : 3.1560373306274414 Secs
# Generation 25325 Bred
# Beginning Natural Selection For Generation : 25325 | Population Size : 103
# Generation 25325 High Score : 7 | Duration : 3.372795820236206 Secs
# Generation 25326 Bred
# Beginning Natural Selection For Generation : 25326 | Population Size : 107
# Generation 25326 High Score : 9 | Duration : 2.9194936752319336 Secs
# Generation 25327 Bred
# Beginning Natural Selection For Generation : 25327 | Population Size : 108
# Generation 25327 High Score : 11 | Duration : 2.718571186065674 Secs
# Generation 25328 Bred
# Beginning Natural Selection For Generation : 25328 | Population Size : 108
# Generation 25328 High Score : 7 | Duration : 3.1034674644470215 Secs
# Generation 25329 Bred
# Beginning Natural Selection For Generation : 25329 | Population Size : 111
# Generation 25329 High Score : 7 | Duration : 2.4676363468170166 Secs
# Generation 25330 Bred
# Beginning Natural Selection For Generation : 25330 | Population Size : 111
# Generation 25330 High Score : 6 | Duration : 2.5603954792022705 Secs
# Generation 25331 Bred
# Beginning Natural Selection For Generation : 25331 | Population Size : 111
# Generation 25331 High Score : 6 | Duration : 3.70809268951416 Secs
# Generation 25332 Bred
# Beginning Natural Selection For Generation : 25332 | Population Size : 111
# Generation 25332 High Score : 8 | Duration : 3.7571966648101807 Secs
# Generation 25333 Bred
# Beginning Natural Selection For Generation : 25333 | Population Size : 111
# Generation 25333 High Score : 8 | Duration : 4.4421706199646 Secs
# Generation 25334 Bred
# Beginning Natural Selection For Generation : 25334 | Population Size : 111
# Generation 25334 High Score : 7 | Duration : 3.4119789600372314 Secs
# Generation 25335 Bred
# Beginning Natural Selection For Generation : 25335 | Population Size : 111
# Generation 25335 High Score : 14 | Duration : 3.182331085205078 Secs
# Generation 25336 Bred
# Beginning Natural Selection For Generation : 25336 | Population Size : 111
# Generation 25336 High Score : 7 | Duration : 4.129690647125244 Secs
# Generation 25337 Bred
# Beginning Natural Selection For Generation : 25337 | Population Size : 111
# Generation 25337 High Score : 5 | Duration : 3.8951239585876465 Secs
# Generation 25338 Bred
# Beginning Natural Selection For Generation : 25338 | Population Size : 111
# Generation 25338 High Score : 12 | Duration : 3.798363208770752 Secs
# Generation 25339 Bred
# Beginning Natural Selection For Generation : 25339 | Population Size : 111
# Generation 25339 High Score : 7 | Duration : 3.6907310485839844 Secs
# Generation 25340 Bred
# Beginning Natural Selection For Generation : 25340 | Population Size : 115
# Generation 25340 High Score : 16 | Duration : 4.3509440422058105 Secs
# Generation 25341 Bred
# Beginning Natural Selection For Generation : 25341 | Population Size : 119
# Generation 25341 High Score : 11 | Duration : 3.9819302558898926 Secs
# Generation 25342 Bred
# Beginning Natural Selection For Generation : 25342 | Population Size : 119
# Generation 25342 High Score : 7 | Duration : 4.388645172119141 Secs
# Generation 25343 Bred
# Beginning Natural Selection For Generation : 25343 | Population Size : 119
# Generation 25343 High Score : 9 | Duration : 3.985893964767456 Secs
# Generation 25344 Bred
# Beginning Natural Selection For Generation : 25344 | Population Size : 119
# Generation 25344 High Score : 9 | Duration : 4.692155599594116 Secs
# Generation 25345 Bred
# Beginning Natural Selection For Generation : 25345 | Population Size : 119
# Generation 25345 High Score : 8 | Duration : 4.271090745925903 Secs
# Generation 25346 Bred
# Beginning Natural Selection For Generation : 25346 | Population Size : 119
# Generation 25346 High Score : 9 | Duration : 4.391540288925171 Secs
# Generation 25347 Bred
# Beginning Natural Selection For Generation : 25347 | Population Size : 119
# Generation 25347 High Score : 6 | Duration : 4.562737703323364 Secs
# Generation 25348 Bred
# Beginning Natural Selection For Generation : 25348 | Population Size : 119
# Generation 25348 High Score : 8 | Duration : 4.502681493759155 Secs
# Generation 25349 Bred
# Beginning Natural Selection For Generation : 25349 | Population Size : 119
# Generation 25349 High Score : 6 | Duration : 3.8975625038146973 Secs
# Generation 25350 Bred
# Beginning Natural Selection For Generation : 25350 | Population Size : 119
# Generation 25350 High Score : 9 | Duration : 3.878260850906372 Secs
# Generation 25351 Bred
# Beginning Natural Selection For Generation : 25351 | Population Size : 119
# Generation 25351 High Score : 15 | Duration : 3.548417568206787 Secs
# Generation 25352 Bred
# Beginning Natural Selection For Generation : 25352 | Population Size : 119
# Generation 25352 High Score : 9 | Duration : 3.9933323860168457 Secs
# Generation 25353 Bred
# Beginning Natural Selection For Generation : 25353 | Population Size : 119
# Generation 25353 High Score : 12 | Duration : 3.391684055328369 Secs
# Generation 25354 Bred
# Beginning Natural Selection For Generation : 25354 | Population Size : 119
# Generation 25354 High Score : 8 | Duration : 4.481394052505493 Secs
# Generation 25355 Bred
# Beginning Natural Selection For Generation : 25355 | Population Size : 119
# Generation 25355 High Score : 8 | Duration : 4.2869627475738525 Secs
# Generation 25356 Bred
# Beginning Natural Selection For Generation : 25356 | Population Size : 119
# Generation 25356 High Score : 11 | Duration : 4.095511436462402 Secs
# Generation 25357 Bred
# Beginning Natural Selection For Generation : 25357 | Population Size : 119
# Generation 25357 High Score : 9 | Duration : 4.0563225746154785 Secs
# Generation 25358 Bred
# Beginning Natural Selection For Generation : 25358 | Population Size : 119
# Generation 25358 High Score : 13 | Duration : 4.084554433822632 Secs
# Generation 25359 Bred
# Beginning Natural Selection For Generation : 25359 | Population Size : 119
# Generation 25359 High Score : 8 | Duration : 4.110385179519653 Secs
# Generation 25360 Bred
# Beginning Natural Selection For Generation : 25360 | Population Size : 119
# Generation 25360 High Score : 8 | Duration : 4.333578586578369 Secs
# Generation 25361 Bred
# Beginning Natural Selection For Generation : 25361 | Population Size : 119
# Generation 25361 High Score : 9 | Duration : 4.316229581832886 Secs
# Generation 25362 Bred
# Beginning Natural Selection For Generation : 25362 | Population Size : 119
# Generation 25362 High Score : 13 | Duration : 4.566212892532349 Secs
# Generation 25363 Bred
# Beginning Natural Selection For Generation : 25363 | Population Size : 119
# Generation 25363 High Score : 5 | Duration : 4.565664768218994 Secs
# Generation 25364 Bred
# Beginning Natural Selection For Generation : 25364 | Population Size : 119
# Generation 25364 High Score : 8 | Duration : 3.542963743209839 Secs
# Generation 25365 Bred
# Beginning Natural Selection For Generation : 25365 | Population Size : 119
# Generation 25365 High Score : 9 | Duration : 4.380710601806641 Secs
# Generation 25366 Bred
# Beginning Natural Selection For Generation : 25366 | Population Size : 119
# Generation 25366 High Score : 7 | Duration : 4.579106330871582 Secs
# Generation 25367 Bred
# Beginning Natural Selection For Generation : 25367 | Population Size : 123
# Generation 25367 High Score : 17 | Duration : 3.6317224502563477 Secs
# Generation 25368 Bred
# Beginning Natural Selection For Generation : 25368 | Population Size : 123
# Generation 25368 High Score : 8 | Duration : 4.770560026168823 Secs
# Generation 25369 Bred
# Beginning Natural Selection For Generation : 25369 | Population Size : 123
# Generation 25369 High Score : 6 | Duration : 4.538435697555542 Secs
# Generation 25370 Bred
# Beginning Natural Selection For Generation : 25370 | Population Size : 127
# Generation 25370 High Score : 11 | Duration : 4.6003944873809814 Secs
# Generation 25371 Bred
# Beginning Natural Selection For Generation : 25371 | Population Size : 127
# Generation 25371 High Score : 9 | Duration : 4.514090538024902 Secs
# Generation 25372 Bred
# Beginning Natural Selection For Generation : 25372 | Population Size : 127
# Generation 25372 High Score : 7 | Duration : 4.398562669754028 Secs
# Generation 25373 Bred
# Beginning Natural Selection For Generation : 25373 | Population Size : 131
# Generation 25373 High Score : 10 | Duration : 5.798233985900879 Secs
# Generation 25374 Bred
# Beginning Natural Selection For Generation : 25374 | Population Size : 131
# Generation 25374 High Score : 6 | Duration : 4.594981908798218 Secs
# Generation 25375 Bred
# Beginning Natural Selection For Generation : 25375 | Population Size : 131
# Generation 25375 High Score : 6 | Duration : 4.260679721832275 Secs
# Generation 25376 Bred
# Beginning Natural Selection For Generation : 25376 | Population Size : 131
# Generation 25376 High Score : 8 | Duration : 4.997191667556763 Secs
# Generation 25377 Bred
# Beginning Natural Selection For Generation : 25377 | Population Size : 131
# Generation 25377 High Score : 10 | Duration : 4.563691139221191 Secs
# Generation 25378 Bred
# Beginning Natural Selection For Generation : 25378 | Population Size : 131
# Generation 25378 High Score : 12 | Duration : 4.65747857093811 Secs
# Generation 25379 Bred
# Beginning Natural Selection For Generation : 25379 | Population Size : 131
# Generation 25379 High Score : 11 | Duration : 5.913344144821167 Secs
# Generation 25380 Bred
# Beginning Natural Selection For Generation : 25380 | Population Size : 131
# Generation 25380 High Score : 7 | Duration : 4.481354236602783 Secs
# Generation 25381 Bred
# Beginning Natural Selection For Generation : 25381 | Population Size : 135
# Generation 25381 High Score : 10 | Duration : 4.075172424316406 Secs
# Generation 25382 Bred
# Beginning Natural Selection For Generation : 25382 | Population Size : 135
# Generation 25382 High Score : 6 | Duration : 5.354810953140259 Secs
# Generation 25383 Bred
# Beginning Natural Selection For Generation : 25383 | Population Size : 135
# Generation 25383 High Score : 6 | Duration : 4.589976072311401 Secs
# Generation 25384 Bred
# Beginning Natural Selection For Generation : 25384 | Population Size : 135
# Generation 25384 High Score : 7 | Duration : 5.287891864776611 Secs
# Generation 25385 Bred
# Beginning Natural Selection For Generation : 25385 | Population Size : 135
# Generation 25385 High Score : 11 | Duration : 5.230356931686401 Secs
# Generation 25386 Bred
# Beginning Natural Selection For Generation : 25386 | Population Size : 135
# Generation 25386 High Score : 8 | Duration : 5.4882731437683105 Secs
# Generation 25387 Bred
# Beginning Natural Selection For Generation : 25387 | Population Size : 135
# Generation 25387 High Score : 8 | Duration : 4.172884702682495 Secs
# Generation 25388 Bred
# Beginning Natural Selection For Generation : 25388 | Population Size : 135
# Generation 25388 High Score : 8 | Duration : 5.620664834976196 Secs
# Generation 25389 Bred
# Beginning Natural Selection For Generation : 25389 | Population Size : 139
# Generation 25389 High Score : 12 | Duration : 5.4684367179870605 Secs
# Generation 25390 Bred
# Beginning Natural Selection For Generation : 25390 | Population Size : 139
# Generation 25390 High Score : 7 | Duration : 5.385063648223877 Secs
# Generation 25391 Bred
# Beginning Natural Selection For Generation : 25391 | Population Size : 139
# Generation 25391 High Score : 6 | Duration : 6.524907827377319 Secs
# Generation 25392 Bred
# Beginning Natural Selection For Generation : 25392 | Population Size : 139
# Generation 25392 High Score : 10 | Duration : 6.092856407165527 Secs
# Generation 25393 Bred
# Beginning Natural Selection For Generation : 25393 | Population Size : 139
# Generation 25393 High Score : 15 | Duration : 5.165873765945435 Secs
# Generation 25394 Bred
# Beginning Natural Selection For Generation : 25394 | Population Size : 139
# Generation 25394 High Score : 7 | Duration : 5.231304883956909 Secs
# Generation 25395 Bred
# Beginning Natural Selection For Generation : 25395 | Population Size : 139
# Generation 25395 High Score : 11 | Duration : 5.939136743545532 Secs
# Generation 25396 Bred
# Beginning Natural Selection For Generation : 25396 | Population Size : 139
# Generation 25396 High Score : 11 | Duration : 6.102777004241943 Secs
# Generation 25397 Bred
# Beginning Natural Selection For Generation : 25397 | Population Size : 139
# Generation 25397 High Score : 9 | Duration : 5.991217613220215 Secs
# Generation 25398 Bred
# Beginning Natural Selection For Generation : 25398 | Population Size : 139
# Generation 25398 High Score : 7 | Duration : 5.704031944274902 Secs
# Generation 25399 Bred
# Beginning Natural Selection For Generation : 25399 | Population Size : 139
# Generation 25399 High Score : 9 | Duration : 4.570676326751709 Secs
# Generation 25400 Bred
# Beginning Natural Selection For Generation : 25400 | Population Size : 45
# Generation 25400 High Score : 10 | Duration : 0.6309504508972168 Secs
# Generation 25401 Bred
# Beginning Natural Selection For Generation : 25401 | Population Size : 45
# Generation 25401 High Score : 5 | Duration : 0.6700935363769531 Secs
# Generation 25402 Bred
# Beginning Natural Selection For Generation : 25402 | Population Size : 45
# Generation 25402 High Score : 5 | Duration : 0.6711196899414062 Secs
# Generation 25403 Bred
# Beginning Natural Selection For Generation : 25403 | Population Size : 47
# Generation 25403 High Score : 10 | Duration : 0.7499871253967285 Secs
# Generation 25404 Bred
# Beginning Natural Selection For Generation : 25404 | Population Size : 47
# Generation 25404 High Score : 6 | Duration : 0.7326278686523438 Secs
# Generation 25405 Bred
# Beginning Natural Selection For Generation : 25405 | Population Size : 47
# Generation 25405 High Score : 4 | Duration : 0.812981367111206 Secs
# Generation 25406 Bred
# Beginning Natural Selection For Generation : 25406 | Population Size : 47
# Generation 25406 High Score : 4 | Duration : 0.6473209857940674 Secs
# Generation 25407 Bred
# Beginning Natural Selection For Generation : 25407 | Population Size : 47
# Generation 25407 High Score : 9 | Duration : 0.7320952415466309 Secs
# Generation 25408 Bred
# Beginning Natural Selection For Generation : 25408 | Population Size : 47
# Generation 25408 High Score : 9 | Duration : 0.757427453994751 Secs
# Generation 25409 Bred
# Beginning Natural Selection For Generation : 25409 | Population Size : 47
# Generation 25409 High Score : 7 | Duration : 0.7733020782470703 Secs
# Generation 25410 Bred
# Beginning Natural Selection For Generation : 25410 | Population Size : 47
# Generation 25410 High Score : 5 | Duration : 0.7474708557128906 Secs
# Generation 25411 Bred
# Beginning Natural Selection For Generation : 25411 | Population Size : 47
# Generation 25411 High Score : 9 | Duration : 0.7013635635375977 Secs
# Generation 25412 Bred
# Beginning Natural Selection For Generation : 25412 | Population Size : 48
# Generation 25412 High Score : 6 | Duration : 0.6130986213684082 Secs
# Generation 25413 Bred
# Beginning Natural Selection For Generation : 25413 | Population Size : 48
# Generation 25413 High Score : 9 | Duration : 0.8015360832214355 Secs
# Generation 25414 Bred
# Beginning Natural Selection For Generation : 25414 | Population Size : 48
# Generation 25414 High Score : 8 | Duration : 0.8466689586639404 Secs
# Generation 25415 Bred
# Beginning Natural Selection For Generation : 25415 | Population Size : 48
# Generation 25415 High Score : 11 | Duration : 0.869032621383667 Secs
# Generation 25416 Bred
# Beginning Natural Selection For Generation : 25416 | Population Size : 48
# Generation 25416 High Score : 4 | Duration : 0.708827018737793 Secs
# Generation 25417 Bred
# Beginning Natural Selection For Generation : 25417 | Population Size : 51
# Generation 25417 High Score : 8 | Duration : 0.842703104019165 Secs
# Generation 25418 Bred
# Beginning Natural Selection For Generation : 25418 | Population Size : 51
# Generation 25418 High Score : 6 | Duration : 0.7852053642272949 Secs
# Generation 25419 Bred
# Beginning Natural Selection For Generation : 25419 | Population Size : 55
# Generation 25419 High Score : 8 | Duration : 1.054492473602295 Secs
# Generation 25420 Bred
# Beginning Natural Selection For Generation : 25420 | Population Size : 55
# Generation 25420 High Score : 5 | Duration : 1.002415418624878 Secs
# Generation 25421 Bred
# Beginning Natural Selection For Generation : 25421 | Population Size : 59
# Generation 25421 High Score : 7 | Duration : 0.9836130142211914 Secs
# Generation 25422 Bred
# Beginning Natural Selection For Generation : 25422 | Population Size : 63
# Generation 25422 High Score : 6 | Duration : 0.9855518341064453 Secs
# Generation 25423 Bred
# Beginning Natural Selection For Generation : 25423 | Population Size : 63
# Generation 25423 High Score : 7 | Duration : 1.3342797756195068 Secs
# Generation 25424 Bred
# Beginning Natural Selection For Generation : 25424 | Population Size : 67
# Generation 25424 High Score : 9 | Duration : 1.4389371871948242 Secs
# Generation 25425 Bred
# Beginning Natural Selection For Generation : 25425 | Population Size : 67
# Generation 25425 High Score : 7 | Duration : 1.618941307067871 Secs
# Generation 25426 Bred
# Beginning Natural Selection For Generation : 25426 | Population Size : 67
# Generation 25426 High Score : 5 | Duration : 1.4795653820037842 Secs
# Generation 25427 Bred
# Beginning Natural Selection For Generation : 25427 | Population Size : 67
# Generation 25427 High Score : 8 | Duration : 1.1686153411865234 Secs
# Generation 25428 Bred
# Beginning Natural Selection For Generation : 25428 | Population Size : 67
# Generation 25428 High Score : 9 | Duration : 1.2856314182281494 Secs
# Generation 25429 Bred
# Beginning Natural Selection For Generation : 25429 | Population Size : 67
# Generation 25429 High Score : 6 | Duration : 1.3481664657592773 Secs
# Generation 25430 Bred
# Beginning Natural Selection For Generation : 25430 | Population Size : 67
# Generation 25430 High Score : 6 | Duration : 1.5038714408874512 Secs
# Generation 25431 Bred
# Beginning Natural Selection For Generation : 25431 | Population Size : 71
# Generation 25431 High Score : 12 | Duration : 1.2975358963012695 Secs
# Generation 25432 Bred
# Beginning Natural Selection For Generation : 25432 | Population Size : 71
# Generation 25432 High Score : 7 | Duration : 1.554999589920044 Secs
# Generation 25433 Bred
# Beginning Natural Selection For Generation : 25433 | Population Size : 71
# ...
# Generation 25436 Bred
# Beginning Natural Selection For Generation : 25436 | Population Size : 71
# Generation 25436 High Score : 6 | Duration : 1.508375883102417 Secs
# Generation 25437 Bred
# Beginning Natural Selection For Generation : 25437 | Population Size : 71
# Generation 25437 High Score : 6 | Duration : 1.5758275985717773 Secs
# Generation 25438 Bred
# Beginning Natural Selection For Generation : 25438 | Population Size : 75
# Generation 25438 High Score : 6 | Duration : 1.1869659423828125 Secs
# Generation 25439 Bred
# Beginning Natural Selection For Generation : 25439 | Population Size : 75
# Generation 25439 High Score : 11 | Duration : 1.6065824031829834 Secs
# Generation 25440 Bred
# Beginning Natural Selection For Generation : 25440 | Population Size : 75
# Generation 25440 High Score : 11 | Duration : 1.5832715034484863 Secs
# Generation 25441 Bred
# Beginning Natural Selection For Generation : 25441 | Population Size : 75
# Generation 25441 High Score : 7 | Duration : 1.5182936191558838 Secs
# Generation 25442 Bred
# Beginning Natural Selection For Generation : 25442 | Population Size : 75
# Generation 25442 High Score : 7 | Duration : 1.3526313304901123 Secs
# Generation 25443 Bred
# Beginning Natural Selection For Generation : 25443 | Population Size : 75
# Generation 25443 High Score : 7 | Duration : 1.721116065979004 Secs
# Generation 25444 Bred
# Beginning Natural Selection For Generation : 25444 | Population Size : 75
# Generation 25444 High Score : 7 | Duration : 1.661142349243164 Secs
# Generation 25445 Bred
# Beginning Natural Selection For Generation : 25445 | Population Size : 75
# Generation 25445 High Score : 12 | Duration : 1.7151634693145752 Secs
# Generation 25446 Bred
# Beginning Natural Selection For Generation : 25446 | Population Size : 75
# Generation 25446 High Score : 6 | Duration : 1.8818635940551758 Secs
# Generation 25447 Bred
# Beginning Natural Selection For Generation : 25447 | Population Size : 75
# Generation 25447 High Score : 6 | Duration : 1.8496263027191162 Secs
# Generation 25448 Bred
# Beginning Natural Selection For Generation : 25448 | Population Size : 75
# Generation 25448 High Score : 9 | Duration : 1.5420618057250977 Secs
# Generation 25449 Bred
# Beginning Natural Selection For Generation : 25449 | Population Size : 75
# Generation 25449 High Score : 6 | Duration : 1.6973514556884766 Secs
# Generation 25450 Bred
# Beginning Natural Selection For Generation : 25450 | Population Size : 75
# Generation 25450 High Score : 15 | Duration : 1.6050975322723389 Secs
# Generation 25451 Bred
# Beginning Natural Selection For Generation : 25451 | Population Size : 75
# Generation 25451 High Score : 6 | Duration : 1.8823189735412598 Secs
# Generation 25452 Bred
# Beginning Natural Selection For Generation : 25452 | Population Size : 75
# Generation 25452 High Score : 13 | Duration : 1.3506076335906982 Secs
# Generation 25453 Bred
# Beginning Natural Selection For Generation : 25453 | Population Size : 75
# Generation 25453 High Score : 9 | Duration : 1.6938717365264893 Secs
# Generation 25454 Bred
# Beginning Natural Selection For Generation : 25454 | Population Size : 75
# Generation 25454 High Score : 9 | Duration : 2.0926225185394287 Secs
# Generation 25455 Bred
# Beginning Natural Selection For Generation : 25455 | Population Size : 75
# Generation 25455 High Score : 6 | Duration : 1.8664817810058594 Secs
# Generation 25456 Bred
# Beginning Natural Selection For Generation : 25456 | Population Size : 75
# Generation 25456 High Score : 10 | Duration : 1.6898696422576904 Secs
# Generation 25457 Bred
# Beginning Natural Selection For Generation : 25457 | Population Size : 75
# Generation 25457 High Score : 5 | Duration : 1.7469100952148438 Secs
# Generation 25458 Bred
# Beginning Natural Selection For Generation : 25458 | Population Size : 79
# Generation 25458 High Score : 7 | Duration : 1.9453091621398926 Secs
# Generation 25459 Bred
# Beginning Natural Selection For Generation : 25459 | Population Size : 79
# Generation 25459 High Score : 7 | Duration : 1.8986873626708984 Secs
# Generation 25460 Bred
# Beginning Natural Selection For Generation : 25460 | Population Size : 79
# Generation 25460 High Score : 5 | Duration : 2.223069429397583 Secs
# Generation 25461 Bred
# Beginning Natural Selection For Generation : 25461 | Population Size : 79
# Generation 25461 High Score : 10 | Duration : 1.4930014610290527 Secs
# Generation 25462 Bred
# Beginning Natural Selection For Generation : 25462 | Population Size : 79
# Generation 25462 High Score : 8 | Duration : 2.0485196113586426 Secs
# Generation 25463 Bred
# Beginning Natural Selection For Generation : 25463 | Population Size : 79
# Generation 25463 High Score : 6 | Duration : 2.2364609241485596 Secs
# Generation 25464 Bred
# Beginning Natural Selection For Generation : 25464 | Population Size : 80
# Generation 25464 High Score : 7 | Duration : 2.1561105251312256 Secs
# Generation 25465 Bred
# Beginning Natural Selection For Generation : 25465 | Population Size : 80
# Generation 25465 High Score : 9 | Duration : 2.0966296195983887 Secs
# Generation 25466 Bred
# Beginning Natural Selection For Generation : 25466 | Population Size : 80
# Generation 25466 High Score : 8 | Duration : 1.9864773750305176 Secs
# Generation 25467 Bred
# Beginning Natural Selection For Generation : 25467 | Population Size : 80
# Generation 25467 High Score : 8 | Duration : 2.0004069805145264 Secs
# Generation 25468 Bred
# Beginning Natural Selection For Generation : 25468 | Population Size : 80
# Generation 25468 High Score : 7 | Duration : 1.7876222133636475 Secs
# Generation 25469 Bred
# Beginning Natural Selection For Generation : 25469 | Population Size : 80
# Generation 25469 High Score : 6 | Duration : 2.2453887462615967 Secs
# Generation 25470 Bred
# Beginning Natural Selection For Generation : 25470 | Population Size : 80
# Generation 25470 High Score : 9 | Duration : 2.051990032196045 Secs
# Generation 25471 Bred
# Beginning Natural Selection For Generation : 25471 | Population Size : 80
# Generation 25471 High Score : 5 | Duration : 2.1843810081481934 Secs
# Generation 25472 Bred
# Beginning Natural Selection For Generation : 25472 | Population Size : 80
# Generation 25472 High Score : 8 | Duration : 1.862518310546875 Secs
# Generation 25473 Bred
# Beginning Natural Selection For Generation : 25473 | Population Size : 80
# Generation 25473 High Score : 5 | Duration : 1.7414937019348145 Secs
# Generation 25474 Bred
# Beginning Natural Selection For Generation : 25474 | Population Size : 80
# Generation 25474 High Score : 10 | Duration : 2.12985897064209 Secs
# Generation 25475 Bred
# Beginning Natural Selection For Generation : 25475 | Population Size : 80
# Generation 25475 High Score : 8 | Duration : 1.9795923233032227 Secs
# Generation 25476 Bred
# Beginning Natural Selection For Generation : 25476 | Population Size : 80
# Generation 25476 High Score : 14 | Duration : 1.4374480247497559 Secs
# Generation 25477 Bred
# Beginning Natural Selection For Generation : 25477 | Population Size : 80
# Generation 25477 High Score : 6 | Duration : 2.018768310546875 Secs
# Generation 25478 Bred
# Beginning Natural Selection For Generation : 25478 | Population Size : 83
# Generation 25478 High Score : 6 | Duration : 1.8694617748260498 Secs
# Generation 25479 Bred
# Beginning Natural Selection For Generation : 25479 | Population Size : 83
# Generation 25479 High Score : 6 | Duration : 2.174999237060547 Secs
# Generation 25480 Bred
# Beginning Natural Selection For Generation : 25480 | Population Size : 83
# Generation 25480 High Score : 6 | Duration : 1.8674800395965576 Secs
# Generation 25481 Bred
# Beginning Natural Selection For Generation : 25481 | Population Size : 83
# Generation 25481 High Score : 7 | Duration : 2.2667171955108643 Secs
# Generation 25482 Bred
# Beginning Natural Selection For Generation : 25482 | Population Size : 83
# Generation 25482 High Score : 8 | Duration : 2.058893918991089 Secs
# Generation 25483 Bred
# Beginning Natural Selection For Generation : 25483 | Population Size : 83
# Generation 25483 High Score : 11 | Duration : 2.297468423843384 Secs
# Generation 25484 Bred
# Beginning Natural Selection For Generation : 25484 | Population Size : 83
# Generation 25484 High Score : 6 | Duration : 2.4735958576202393 Secs
# Generation 25485 Bred
# Beginning Natural Selection For Generation : 25485 | Population Size : 83
# Generation 25485 High Score : 8 | Duration : 2.3575265407562256 Secs
# Generation 25486 Bred
# Beginning Natural Selection For Generation : 25486 | Population Size : 83
# Generation 25486 High Score : 6 | Duration : 2.121432304382324 Secs
# Generation 25487 Bred
# Beginning Natural Selection For Generation : 25487 | Population Size : 83
# Generation 25487 High Score : 13 | Duration : 2.1690030097961426 Secs
# Generation 25488 Bred
# Beginning Natural Selection For Generation : 25488 | Population Size : 83
# Generation 25488 High Score : 11 | Duration : 2.1993041038513184 Secs
# Generation 25489 Bred
# Beginning Natural Selection For Generation : 25489 | Population Size : 83
# Generation 25489 High Score : 6 | Duration : 1.8981897830963135 Secs
# Generation 25490 Bred
# Beginning Natural Selection For Generation : 25490 | Population Size : 83
# Generation 25490 High Score : 7 | Duration : 1.8387129306793213 Secs
# Generation 25491 Bred
# Beginning Natural Selection For Generation : 25491 | Population Size : 83
# Generation 25491 High Score : 9 | Duration : 2.057941436767578 Secs
# Generation 25492 Bred
# Beginning Natural Selection For Generation : 25492 | Population Size : 83
# Generation 25492 High Score : 7 | Duration : 2.2974679470062256 Secs
# Generation 25493 Bred
# Beginning Natural Selection For Generation : 25493 | Population Size : 83
# Generation 25493 High Score : 5 | Duration : 2.301480531692505 Secs
# Generation 25494 Bred
# Beginning Natural Selection For Generation : 25494 | Population Size : 83
# Generation 25494 High Score : 7 | Duration : 1.9587435722351074 Secs
# Generation 25495 Bred
# Beginning Natural Selection For Generation : 25495 | Population Size : 87
# Generation 25495 High Score : 7 | Duration : 2.0549252033233643 Secs
# Generation 25496 Bred
# Beginning Natural Selection For Generation : 25496 | Population Size : 91
# Generation 25496 High Score : 8 | Duration : 2.4422993659973145 Secs
# Generation 25497 Bred
# Beginning Natural Selection For Generation : 25497 | Population Size : 91
# Generation 25497 High Score : 11 | Duration : 2.541048049926758 Secs
# Generation 25498 Bred
# Beginning Natural Selection For Generation : 25498 | Population Size : 91
# Generation 25498 High Score : 7 | Duration : 2.7612709999084473 Secs
# Generation 25499 Bred
# Beginning Natural Selection For Generation : 25499 | Population Size : 95
# Generation 25499 High Score : 9 | Duration : 2.530137300491333 Secs
# Generation 25500 Bred
# Beginning Natural Selection For Generation : 25500 | Population Size : 95
# Generation 25500 High Score : 6 | Duration : 2.5910985469818115 Secs
# Generation 25501 Bred
# Beginning Natural Selection For Generation : 25501 | Population Size : 95
# Generation 25501 High Score : 9 | Duration : 2.878324031829834 Secs
# Generation 25502 Bred
# Beginning Natural Selection For Generation : 25502 | Population Size : 95
# Generation 25502 High Score : 10 | Duration : 2.5430262088775635 Secs
# Generation 25503 Bred
# Beginning Natural Selection For Generation : 25503 | Population Size : 95
# Generation 25503 High Score : 11 | Duration : 2.672941207885742 Secs
# Generation 25504 Bred
# Beginning Natural Selection For Generation : 25504 | Population Size : 95
# Generation 25504 High Score : 10 | Duration : 2.8361685276031494 Secs
# Generation 25505 Bred
# Beginning Natural Selection For Generation : 25505 | Population Size : 95
# Generation 25505 High Score : 9 | Duration : 2.5752274990081787 Secs
# Generation 25506 Bred
# Beginning Natural Selection For Generation : 25506 | Population Size : 95
# Generation 25506 High Score : 11 | Duration : 2.8688595294952393 Secs
# Generation 25507 Bred
# Beginning Natural Selection For Generation : 25507 | Population Size : 95
# Generation 25507 High Score : 8 | Duration : 2.8366611003875732 Secs
# Generation 25508 Bred
# Beginning Natural Selection For Generation : 25508 | Population Size : 99
# Generation 25508 High Score : 15 | Duration : 2.194300889968872 Secs
# Generation 25509 Bred
# Beginning Natural Selection For Generation : 25509 | Population Size : 99
# Generation 25509 High Score : 13 | Duration : 2.786072254180908 Secs
# Generation 25510 Bred
# Beginning Natural Selection For Generation : 25510 | Population Size : 100
# Generation 25510 High Score : 9 | Duration : 2.512176990509033 Secs
# Generation 25511 Bred
# Beginning Natural Selection For Generation : 25511 | Population Size : 100
# Generation 25511 High Score : 8 | Duration : 3.1094207763671875 Secs
# Generation 25512 Bred
# Beginning Natural Selection For Generation : 25512 | Population Size : 100
# Generation 25512 High Score : 7 | Duration : 3.199198007583618 Secs
# Generation 25513 Bred
# Beginning Natural Selection For Generation : 25513 | Population Size : 100
# Generation 25513 High Score : 7 | Duration : 2.785571575164795 Secs
# Generation 25514 Bred
# Beginning Natural Selection For Generation : 25514 | Population Size : 100
# Generation 25514 High Score : 8 | Duration : 2.907093048095703 Secs
# Generation 25515 Bred
# Beginning Natural Selection For Generation : 25515 | Population Size : 100
# Generation 25515 High Score : 11 | Duration : 3.0583319664001465 Secs
# Generation 25516 Bred
# Beginning Natural Selection For Generation : 25516 | Population Size : 100
# Generation 25516 High Score : 7 | Duration : 3.082676410675049 Secs
# Generation 25517 Bred
# Beginning Natural Selection For Generation : 25517 | Population Size : 100
# Generation 25517 High Score : 7 | Duration : 2.7821035385131836 Secs
# Generation 25518 Bred
# Beginning Natural Selection For Generation : 25518 | Population Size : 100
# Generation 25518 High Score : 7 | Duration : 3.1932411193847656 Secs
# Generation 25519 Bred
# Beginning Natural Selection For Generation : 25519 | Population Size : 100
# Generation 25519 High Score : 10 | Duration : 2.782099723815918 Secs
# Generation 25520 Bred
# Beginning Natural Selection For Generation : 25520 | Population Size : 100
# Generation 25520 High Score : 8 | Duration : 3.108968496322632 Secs
# Generation 25521 Bred
# Beginning Natural Selection For Generation : 25521 | Population Size : 100
# Generation 25521 High Score : 7 | Duration : 2.8554677963256836 Secs
# Generation 25522 Bred
# Beginning Natural Selection For Generation : 25522 | Population Size : 103
# Generation 25522 High Score : 11 | Duration : 2.9085400104522705 Secs
# Generation 25523 Bred
# Beginning Natural Selection For Generation : 25523 | Population Size : 103
# Generation 25523 High Score : 6 | Duration : 3.346055269241333 Secs
# Generation 25524 Bred
# Beginning Natural Selection For Generation : 25524 | Population Size : 103
# Generation 25524 High Score : 8 | Duration : 3.2612409591674805 Secs
# Generation 25525 Bred
# Beginning Natural Selection For Generation : 25525 | Population Size : 103
# Generation 25525 High Score : 5 | Duration : 3.0266261100769043 Secs
# Generation 25526 Bred
# Beginning Natural Selection For Generation : 25526 | Population Size : 103
# Generation 25526 High Score : 12 | Duration : 2.7235324382781982 Secs
# Generation 25527 Bred
# Beginning Natural Selection For Generation : 25527 | Population Size : 103
# Generation 25527 High Score : 6 | Duration : 2.908085346221924 Secs
# Generation 25528 Bred
# Beginning Natural Selection For Generation : 25528 | Population Size : 107
# Generation 25528 High Score : 13 | Duration : 2.692331314086914 Secs
# Generation 25529 Bred
# Beginning Natural Selection For Generation : 25529 | Population Size : 107
# Generation 25529 High Score : 7 | Duration : 4.3073015213012695 Secs
# Generation 25530 Bred
# Beginning Natural Selection For Generation : 25530 | Population Size : 107
# Generation 25530 High Score : 5 | Duration : 3.4234306812286377 Secs
# Generation 25531 Bred
# Beginning Natural Selection For Generation : 25531 | Population Size : 107
# Generation 25531 High Score : 9 | Duration : 3.394167184829712 Secs
# Generation 25532 Bred
# Beginning Natural Selection For Generation : 25532 | Population Size : 111

# %%
population = load_wrapped_net_population('eigthTrial')[0]

# %%
population  = population[:30]
len(population)
# Out:
# 30

# %%
logic_engine_1 = logic_engine_wrapper(logic_engine=population[3][0])
logic_engine_2 = logic_engine_wrapper(logic_engine=population[5][0])
result = play_game(logic_engines=[logic_engine_1,logic_engine_2],verbose=True,ai_delay=0)
# Out:
# |       |
# |       |
# |       |
# |       |
# |       |
# |       |
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |       |
# |       |
# |#      |
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |       |
# |       |
# |#     @|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |       |
# |#      |
# |#     @|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |#      |
# |#     @|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |#      |
# |#    #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |#      |
# |#@   #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |##     |
# |#@   #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@      |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |       |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |       |
# |       |
# |@      |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |       |
# |#      |
# |@      |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |       |
# |#      |
# |@@     |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@#     |
# |##     |
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@#     |
# |##    @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@#     |
# |###   @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@#     |
# |###   @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |###   @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |###   @|
# |#@@  #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |###   @|
# |#@@# #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |###   @|
# |#@@# #@|
# ---------
#  1234567
# Thinking...
# |#      |
# |#      |
# |@@     |
# |@##    |
# |####  @|
# |#@@# #@|
# ---------
#  1234567

# %%
len(generate_standard_net().hidden_layers[0])
# Out:
# 42
